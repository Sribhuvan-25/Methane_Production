# %%
import numpy as np # Version 1.16.0

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
import pandas as pd
import keras # Version 2.2.4
from sklearn.metrics import r2_score
import innvestigate as inn # Version 1.0.8
print("tensorflow version:", tf.__version__)
print("keras version:", keras.__version__)
# Out:
# tensorflow version: 2.13.0
# keras version: 2.13.1

# %% [markdown]
# ## LRP with 5-fold CV

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from scipy.cluster.hierarchy import linkage, leaves_list
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers.legacy import Adam  # Use legacy optimizer for M1/M2 Macs
import innvestigate  # For LRP

# -------------------------------------------------------------
# DISABLE EAGER EXECUTION
# -------------------------------------------------------------
tf.compat.v1.disable_eager_execution()

# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')
X = df.drop(columns=target_columns)
y = df[target_columns].apply(pd.to_numeric, errors='coerce')

# Feature Preprocessing
num_features = 500
if X.shape[1] > num_features:
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

corr = X.corr().fillna(0)
Z = linkage(1 - corr, method='average')
leaf_order = leaves_list(Z)
X = X.iloc[:, leaf_order]

num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))
padding = grid_size**2 - num_features_final
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# -------------------------------------------------------------
# DEFINE CNN MODEL
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = Sequential([
        Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        Conv2D(32, kernel_size=(3, 3), activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

# -------------------------------------------------------------
# CROSS-VALIDATION WITH LRP
# -------------------------------------------------------------
target_column = 'H2-km'
all_y_true, all_y_pred = [], []
lrp_cache = pd.DataFrame(index=X.columns)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
X_values = X.values
y_values = y[target_column].values.astype(float)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_values)

for fold, (train_idx, val_idx) in enumerate(kf.split(X_scaled)):
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y_values[train_idx], y_values[val_idx]

    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)

    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1, validation_data=(X_val, y_val))

    preds = model.predict(X_val).flatten()
    all_y_true.extend(y_val)
    all_y_pred.extend(preds)

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)

    # Ensure the input shape for LRP matches the model's input
    relevance_scores = analyzer.analyze(X_train).mean(axis=0)
    relevance_df = pd.DataFrame(relevance_scores.flatten(), index=X.columns, columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, relevance_df], axis=1)

# -------------------------------------------------------------
# EVALUATE PERFORMANCE
# -------------------------------------------------------------
all_y_true = np.array(all_y_true)
all_y_pred = np.array(all_y_pred)

r2 = r2_score(all_y_true, all_y_pred)
mse = mean_squared_error(all_y_true, all_y_pred)
print(f"R2 Score: {r2:.4f}")
print(f"MSE: {mse:.4f}")

# -------------------------------------------------------------
# PLOT: Predicted vs Actual Values
# -------------------------------------------------------------
plt.figure(figsize=(8, 8))
plt.scatter(all_y_true, all_y_pred, alpha=0.6, edgecolors='k', label='Validation Points')
plt.plot([min(all_y_true), max(all_y_true)], [min(all_y_true), max(all_y_true)], 'r--', label='Ideal Fit')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'Predicted vs Actual Values ({target_column})')
plt.legend()
plt.grid(True)
plt.show()

# -------------------------------------------------------------
# SAVE: Top 30 Features by Relevance
# -------------------------------------------------------------
# Ensure the Mean_Abs_Relevance column is computed
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache_sorted = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

# Select top 30 features and save to CSV
top_30_features = lrp_cache_sorted.head(30)
top_30_features.to_csv("top_30_features.csv", index=True)

print("Top 30 features saved to 'top_30_features.csv'.")

# -------------------------------------------------------------
# LRP RESULTS
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

lrp_cache.to_csv("lrp_feature_relevance.csv")
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Train on 43 samples, validate on 11 samples
# Epoch 1/30
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_71469/324946927.py:47: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')
# 2025-01-28 11:34:04.275956: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-01-28 11:34:04.275980: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-01-28 11:34:04.275987: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-01-28 11:34:04.276022: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-01-28 11:34:04.276040: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-01-28 11:34:04.281780: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2025-01-28 11:34:04.284256: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:04.299235: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/conv2d_1/kernel/v/Assign' id:294 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d_1/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d_1/kernel/v, training/Adam/conv2d_1/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:04.303043: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:04.338310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 9ms/sample - loss: 2760.5133 - val_loss: 1569.7540
# Epoch 2/30
# 43/43 [==============================] - 0s 581us/sample - loss: 2445.6696 - val_loss: 1285.0745
# Epoch 3/30
# 43/43 [==============================] - 0s 396us/sample - loss: 2047.9887 - val_loss: 948.8640
# Epoch 4/30
# 43/43 [==============================] - 0s 533us/sample - loss: 1628.0728 - val_loss: 651.6035
# Epoch 5/30
# 43/43 [==============================] - 0s 402us/sample - loss: 1204.1352 - val_loss: 553.4033
# Epoch 6/30
# 43/43 [==============================] - 0s 399us/sample - loss: 894.0215 - val_loss: 705.4115
# Epoch 7/30
# 43/43 [==============================] - 0s 394us/sample - loss: 926.8371 - val_loss: 822.6584
# Epoch 8/30
# 43/43 [==============================] - 0s 384us/sample - loss: 943.7050 - val_loss: 685.6049
# Epoch 9/30
# 43/43 [==============================] - 0s 378us/sample - loss: 773.4828 - val_loss: 511.4759
# Epoch 10/30
# 32/43 [=====================>........] - ETA: 0s - loss: 529.5366
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:34:04.624008: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:117 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:04.628001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 382us/sample - loss: 641.3389 - val_loss: 447.2950
# Epoch 11/30
# 43/43 [==============================] - 0s 398us/sample - loss: 575.2503 - val_loss: 453.4173
# Epoch 12/30
# 43/43 [==============================] - 0s 371us/sample - loss: 567.0424 - val_loss: 469.1036
# Epoch 13/30
# 43/43 [==============================] - 0s 389us/sample - loss: 526.5122 - val_loss: 461.9928
# Epoch 14/30
# 43/43 [==============================] - 0s 395us/sample - loss: 455.4357 - val_loss: 435.7192
# Epoch 15/30
# 43/43 [==============================] - 0s 370us/sample - loss: 374.6979 - val_loss: 398.2396
# Epoch 16/30
# 43/43 [==============================] - 0s 395us/sample - loss: 309.4289 - val_loss: 366.5992
# Epoch 17/30
# 43/43 [==============================] - 0s 383us/sample - loss: 281.3835 - val_loss: 347.4869
# Epoch 18/30
# 43/43 [==============================] - 0s 389us/sample - loss: 277.5388 - val_loss: 343.4525
# Epoch 19/30
# 43/43 [==============================] - 0s 386us/sample - loss: 270.4517 - val_loss: 360.1641
# Epoch 20/30
# 43/43 [==============================] - 0s 371us/sample - loss: 246.8627 - val_loss: 400.2007
# Epoch 21/30
# 43/43 [==============================] - 0s 398us/sample - loss: 221.1579 - val_loss: 451.0787
# Epoch 22/30
# 43/43 [==============================] - 0s 379us/sample - loss: 210.6977 - val_loss: 501.0726
# Epoch 23/30
# 43/43 [==============================] - 0s 1ms/sample - loss: 215.0160 - val_loss: 541.4417
# Epoch 24/30
# 43/43 [==============================] - 0s 392us/sample - loss: 221.4285 - val_loss: 555.6061
# Epoch 25/30
# 43/43 [==============================] - 0s 379us/sample - loss: 222.4619 - val_loss: 547.8780
# Epoch 26/30
# 43/43 [==============================] - 0s 398us/sample - loss: 215.6173 - val_loss: 522.5811
# Epoch 27/30
# 43/43 [==============================] - 0s 408us/sample - loss: 205.6285 - val_loss: 481.0315
# Epoch 28/30
# 43/43 [==============================] - 0s 395us/sample - loss: 193.6180 - val_loss: 440.2319
# Epoch 29/30
# 43/43 [==============================] - 0s 387us/sample - loss: 195.6200 - val_loss: 407.8078
# Epoch 30/30
# 43/43 [==============================] - 0s 377us/sample - loss: 193.4648 - val_loss: 403.7579
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:34:05.216651: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:99 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.220723: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.310742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.314667: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_2/Assign' id:461 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.319665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.335145: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.352898: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:491 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.357925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.360711: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:487 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.365854: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.368871: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:493 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.373949: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.378357: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:401 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.383265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.387116: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:508 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.392143: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.395394: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:505 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.400561: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.408723: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:448 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.414015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.431876: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:532 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.437622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.441186: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:529 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.446405: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.456142: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:428 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.461802: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.479696: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:428 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.484958: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.500456: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:550 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.505753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.509149: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:547 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.514297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.522710: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:408 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.528127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.545532: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:408 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.551233: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.565758: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:567 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.571222: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.574601: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:564 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.580043: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.592794: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train on 43 samples, validate on 11 samples
# Epoch 1/30
# 32/43 [=====================>........] - ETA: 0s - loss: 2393.4507
# 2025-01-28 11:34:05.827970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.841577: W tensorflow/c/c_api.cc:304] Operation '{name:'training_2/Adam/conv2d_2/bias/m/Assign' id:820 op device:{requested: '', assigned: ''} def:{{{node training_2/Adam/conv2d_2/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_2/Adam/conv2d_2/bias/m, training_2/Adam/conv2d_2/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:05.850782: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:05.885655: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 7ms/sample - loss: 2255.3389 - val_loss: 3606.2954
# Epoch 2/30
# 43/43 [==============================] - 0s 368us/sample - loss: 2083.6755 - val_loss: 3267.6455
# Epoch 3/30
# 43/43 [==============================] - 0s 405us/sample - loss: 1879.3613 - val_loss: 2787.9402
# Epoch 4/30
# 43/43 [==============================] - 0s 385us/sample - loss: 1561.3386 - val_loss: 2165.8943
# Epoch 5/30
# 43/43 [==============================] - 0s 385us/sample - loss: 1227.5846 - val_loss: 1466.3682
# Epoch 6/30
# 43/43 [==============================] - 0s 390us/sample - loss: 939.5298 - val_loss: 898.6779
# Epoch 7/30
# 43/43 [==============================] - 0s 384us/sample - loss: 886.3784 - val_loss: 708.9619
# Epoch 8/30
# 43/43 [==============================] - 0s 385us/sample - loss: 989.0275 - val_loss: 658.0027
# Epoch 9/30
# 43/43 [==============================] - 0s 389us/sample - loss: 927.1278 - val_loss: 646.7004
# Epoch 10/30
# 43/43 [==============================] - 0s 384us/sample - loss: 773.1613 - val_loss: 679.7859
# Epoch 11/30
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:34:06.062428: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:696 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.072046: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 384us/sample - loss: 699.6074 - val_loss: 738.1721
# Epoch 12/30
# 43/43 [==============================] - 0s 394us/sample - loss: 674.2604 - val_loss: 767.1535
# Epoch 13/30
# 43/43 [==============================] - 0s 376us/sample - loss: 651.4936 - val_loss: 731.2519
# Epoch 14/30
# 43/43 [==============================] - 0s 387us/sample - loss: 625.5853 - val_loss: 653.5112
# Epoch 15/30
# 43/43 [==============================] - 0s 369us/sample - loss: 584.1794 - val_loss: 535.5092
# Epoch 16/30
# 43/43 [==============================] - 0s 383us/sample - loss: 532.8188 - val_loss: 388.9744
# Epoch 17/30
# 43/43 [==============================] - 0s 386us/sample - loss: 482.9528 - val_loss: 269.2268
# Epoch 18/30
# 43/43 [==============================] - 0s 394us/sample - loss: 440.9010 - val_loss: 194.7540
# Epoch 19/30
# 43/43 [==============================] - 0s 420us/sample - loss: 414.0416 - val_loss: 152.9642
# Epoch 20/30
# 43/43 [==============================] - 0s 423us/sample - loss: 375.5703 - val_loss: 125.4024
# Epoch 21/30
# 43/43 [==============================] - 0s 385us/sample - loss: 341.0278 - val_loss: 104.3001
# Epoch 22/30
# 43/43 [==============================] - 0s 1ms/sample - loss: 307.7784 - val_loss: 91.9288
# Epoch 23/30
# 43/43 [==============================] - 0s 374us/sample - loss: 276.5750 - val_loss: 87.1637
# Epoch 24/30
# 43/43 [==============================] - 0s 385us/sample - loss: 261.7651 - val_loss: 89.5035
# Epoch 25/30
# 43/43 [==============================] - 0s 394us/sample - loss: 242.8476 - val_loss: 104.5005
# Epoch 26/30
# 43/43 [==============================] - 0s 378us/sample - loss: 233.1114 - val_loss: 142.0727
# Epoch 27/30
# 43/43 [==============================] - 0s 400us/sample - loss: 227.3061 - val_loss: 198.3240
# Epoch 28/30
# 43/43 [==============================] - 0s 383us/sample - loss: 232.4970 - val_loss: 248.6260
# Epoch 29/30
# 43/43 [==============================] - 0s 383us/sample - loss: 231.5021 - val_loss: 258.8895
# Epoch 30/30
# 43/43 [==============================] - 0s 387us/sample - loss: 227.4092 - val_loss: 248.9708
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:34:06.648802: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:678 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.658247: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.715527: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.720516: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_5/Assign' id:1018 op device:{requested: '', assigned: ''} def:{{{node kernel_5/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_5, kernel_5/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.730644: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.748716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.765374: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/range' id:1068 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_6/MaxNeuronSelection_1/Max_grad/range/start, gradients_6/MaxNeuronSelection_1/Max_grad/Size, gradients_6/MaxNeuronSelection_1/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.775668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.779579: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/mod' id:1064 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_6/MaxNeuronSelection_1/Max_grad/add, gradients_6/MaxNeuronSelection_1/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.790224: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.794299: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/ones' id:1070 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_6/MaxNeuronSelection_1/Max_grad/Shape_1, gradients_6/MaxNeuronSelection_1/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.804563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.809480: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_1/Max/reduction_indices' id:978 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_1/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.819643: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.824985: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_12/x' id:1085 op device:{requested: '', assigned: ''} def:{{{node mul_12/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.835065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.839263: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_4' id:1082 op device:{requested: '', assigned: ''} def:{{{node Const_4}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.850013: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.859728: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_10' id:1025 op device:{requested: '', assigned: ''} def:{{{node mul_10}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_10)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.870529: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.887618: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_13/x' id:1109 op device:{requested: '', assigned: ''} def:{{{node mul_13/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.898144: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.902867: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_5' id:1106 op device:{requested: '', assigned: ''} def:{{{node Const_5}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.913163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.923850: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_9' id:1005 op device:{requested: '', assigned: ''} def:{{{node mul_9}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast_9)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.934370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.950429: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_9' id:1005 op device:{requested: '', assigned: ''} def:{{{node mul_9}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast_9)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.960904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.977435: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_14/x' id:1127 op device:{requested: '', assigned: ''} def:{{{node mul_14/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:06.987965: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:06.992136: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_6' id:1124 op device:{requested: '', assigned: ''} def:{{{node Const_6}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.002426: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.011886: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_8' id:985 op device:{requested: '', assigned: ''} def:{{{node mul_8}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_9, Cast_8)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.022656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.038384: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_8' id:985 op device:{requested: '', assigned: ''} def:{{{node mul_8}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_9, Cast_8)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.048947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.065889: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_15/x' id:1144 op device:{requested: '', assigned: ''} def:{{{node mul_15/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.076954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.081212: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_7' id:1141 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.091807: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.112435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train on 43 samples, validate on 11 samples
# Epoch 1/30
# 32/43 [=====================>........] - ETA: 0s - loss: 2911.2480
# 2025-01-28 11:34:07.335325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.350934: W tensorflow/c/c_api.cc:304] Operation '{name:'training_4/Adam/conv2d_5/kernel/m/Assign' id:1404 op device:{requested: '', assigned: ''} def:{{{node training_4/Adam/conv2d_5/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_4/Adam/conv2d_5/kernel/m, training_4/Adam/conv2d_5/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.365125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:07.401087: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 7ms/sample - loss: 2716.1173 - val_loss: 1817.6857
# Epoch 2/30
# 43/43 [==============================] - 0s 384us/sample - loss: 2486.1586 - val_loss: 1580.9969
# Epoch 3/30
# 43/43 [==============================] - 0s 400us/sample - loss: 2135.3012 - val_loss: 1278.2335
# Epoch 4/30
# 43/43 [==============================] - 0s 404us/sample - loss: 1721.8482 - val_loss: 982.5002
# Epoch 5/30
# 43/43 [==============================] - 0s 370us/sample - loss: 1224.9931 - val_loss: 850.0084
# Epoch 6/30
# 43/43 [==============================] - 0s 394us/sample - loss: 865.6163 - val_loss: 1089.8101
# Epoch 7/30
# 43/43 [==============================] - 0s 380us/sample - loss: 882.1396 - val_loss: 1352.8948
# Epoch 8/30
# 43/43 [==============================] - 0s 395us/sample - loss: 1052.0104 - val_loss: 1218.4910
# Epoch 9/30
# 32/43 [=====================>........] - ETA: 0s - loss: 1080.2529
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:34:07.583572: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_2/mul' id:1273 op device:{requested: '', assigned: ''} def:{{{node loss_2/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_2/mul/x, loss_2/dense_5_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:07.598629: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 1ms/sample - loss: 911.0288 - val_loss: 909.9646
# Epoch 10/30
# 43/43 [==============================] - 0s 479us/sample - loss: 661.6238 - val_loss: 720.2583
# Epoch 11/30
# 43/43 [==============================] - 0s 385us/sample - loss: 573.5297 - val_loss: 647.1674
# Epoch 12/30
# 43/43 [==============================] - 0s 371us/sample - loss: 572.7077 - val_loss: 624.3836
# Epoch 13/30
# 43/43 [==============================] - 0s 389us/sample - loss: 579.7857 - val_loss: 595.1592
# Epoch 14/30
# 43/43 [==============================] - 0s 685us/sample - loss: 534.3045 - val_loss: 547.8567
# Epoch 15/30
# 43/43 [==============================] - 0s 409us/sample - loss: 460.5907 - val_loss: 495.3141
# Epoch 16/30
# 43/43 [==============================] - 0s 392us/sample - loss: 376.1219 - val_loss: 455.8710
# Epoch 17/30
# 43/43 [==============================] - 0s 398us/sample - loss: 325.3948 - val_loss: 431.4360
# Epoch 18/30
# 43/43 [==============================] - 0s 402us/sample - loss: 305.6204 - val_loss: 405.3698
# Epoch 19/30
# 43/43 [==============================] - 0s 379us/sample - loss: 305.5927 - val_loss: 366.7137
# Epoch 20/30
# 43/43 [==============================] - 0s 389us/sample - loss: 293.1310 - val_loss: 324.3420
# Epoch 21/30
# 43/43 [==============================] - 0s 385us/sample - loss: 267.3828 - val_loss: 293.1363
# Epoch 22/30
# 43/43 [==============================] - 0s 383us/sample - loss: 246.9774 - val_loss: 271.1567
# Epoch 23/30
# 43/43 [==============================] - 0s 371us/sample - loss: 235.7439 - val_loss: 259.5559
# Epoch 24/30
# 43/43 [==============================] - 0s 361us/sample - loss: 235.8085 - val_loss: 255.9401
# Epoch 25/30
# 43/43 [==============================] - 0s 377us/sample - loss: 226.7844 - val_loss: 246.2351
# Epoch 26/30
# 43/43 [==============================] - 0s 383us/sample - loss: 222.3071 - val_loss: 233.8367
# Epoch 27/30
# 43/43 [==============================] - 0s 388us/sample - loss: 217.0506 - val_loss: 223.3193
# Epoch 28/30
# 43/43 [==============================] - 0s 372us/sample - loss: 209.3269 - val_loss: 217.6055
# Epoch 29/30
# 43/43 [==============================] - 0s 396us/sample - loss: 203.1511 - val_loss: 213.6664
# Epoch 30/30
# 43/43 [==============================] - 0s 370us/sample - loss: 195.3607 - val_loss: 212.4630
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:34:08.183455: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_5/BiasAdd' id:1255 op device:{requested: '', assigned: ''} def:{{{node dense_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_5/MatMul, dense_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:08.198453: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:08.259747: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:08.265545: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_10/Assign' id:1615 op device:{requested: '', assigned: ''} def:{{{node kernel_10/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_10, kernel_10/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:08.280442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:08.298190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:08.314854: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/range' id:1645 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_12/MaxNeuronSelection_2/Max_grad/range/start, gradients_12/MaxNeuronSelection_2/Max_grad/Size, gradients_12/MaxNeuronSelection_2/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:08.329979: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:08.334855: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/mod' id:1641 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_12/MaxNeuronSelection_2/Max_grad/add, gradients_12/MaxNeuronSelection_2/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:08.350500: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...
# 2025-01-28 11:34:11.743693: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.820124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.827740: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_16/Assign' id:2729 op device:{requested: '', assigned: ''} def:{{{node kernel_16/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_16, kernel_16/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:11.852886: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.873798: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.893504: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_24/MaxNeuronSelection_4/Max_grad/range' id:2799 op device:{requested: '', assigned: ''} def:{{{node gradients_24/MaxNeuronSelection_4/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_4/Max"], _has_manual_control_dependencies=true](gradients_24/MaxNeuronSelection_4/Max_grad/range/start, gradients_24/MaxNeuronSelection_4/Max_grad/Size, gradients_24/MaxNeuronSelection_4/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:11.919653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.926618: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_24/MaxNeuronSelection_4/Max_grad/mod' id:2795 op device:{requested: '', assigned: ''} def:{{{node gradients_24/MaxNeuronSelection_4/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_4/Max"], _has_manual_control_dependencies=true](gradients_24/MaxNeuronSelection_4/Max_grad/add, gradients_24/MaxNeuronSelection_4/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:11.953152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.959697: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_24/MaxNeuronSelection_4/Max_grad/ones' id:2801 op device:{requested: '', assigned: ''} def:{{{node gradients_24/MaxNeuronSelection_4/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_4/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_24/MaxNeuronSelection_4/Max_grad/Shape_1, gradients_24/MaxNeuronSelection_4/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:11.985779: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:11.993633: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_4/Max/reduction_indices' id:2709 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_4/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.019238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.027382: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_36/x' id:2816 op device:{requested: '', assigned: ''} def:{{{node mul_36/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.053818: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.061096: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_16' id:2813 op device:{requested: '', assigned: ''} def:{{{node Const_16}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.086166: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.098132: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_34' id:2756 op device:{requested: '', assigned: ''} def:{{{node mul_34}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_37, Cast_34)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.123662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.144802: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_37/x' id:2840 op device:{requested: '', assigned: ''} def:{{{node mul_37/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.170240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.177794: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_17' id:2837 op device:{requested: '', assigned: ''} def:{{{node Const_17}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.203086: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.216585: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_33' id:2736 op device:{requested: '', assigned: ''} def:{{{node mul_33}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_35, Cast_33)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.242061: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.261013: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_33' id:2736 op device:{requested: '', assigned: ''} def:{{{node mul_33}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_35, Cast_33)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.286752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.306743: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_38/x' id:2858 op device:{requested: '', assigned: ''} def:{{{node mul_38/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.331678: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.339052: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_18' id:2855 op device:{requested: '', assigned: ''} def:{{{node Const_18}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.364901: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.377343: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_32' id:2716 op device:{requested: '', assigned: ''} def:{{{node mul_32}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_33, Cast_32)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.403698: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.422952: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_32' id:2716 op device:{requested: '', assigned: ''} def:{{{node mul_32}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_33, Cast_32)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.448397: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.467864: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_39/x' id:2875 op device:{requested: '', assigned: ''} def:{{{node mul_39/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.494101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.501301: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_19' id:2872 op device:{requested: '', assigned: ''} def:{{{node Const_19}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:34:12.527103: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:34:12.565925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# R2 Score: 0.6762
# MSE: 311.2395
# Top 30 features saved to 'top_30_features.csv'.
#
# Top 10 Features by Relevance:
#                                                       Fold_0    Fold_1  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.861436  0.900692
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.696196  0.603824
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...  0.473985  0.539549
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.515205  0.487454
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Euba...  0.576301  0.435986
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.516751  0.455672
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.547506  0.377497
# d__Bacteria;p__Chloroflexi;c__Dehalococcoidia;o...  0.359693  0.372686
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.473929  0.449988
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.414698  0.430313
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.929908  0.825330
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.635780  0.636560
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...  0.532766  0.660988
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.589439  0.516628
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Euba...  0.397899  0.419406
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.457228  0.406042
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.470920  0.413783
# d__Bacteria;p__Chloroflexi;c__Dehalococcoidia;o...  0.536963  0.533838
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.459244  0.333576
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.317003  0.453795
#
#                                                       Fold_4  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.786700
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.696336
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...  0.540044
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.531976
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Euba...  0.521928
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.404151
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.411809
# d__Bacteria;p__Chloroflexi;c__Dehalococcoidia;o...  0.396708
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.344791
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.415848
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.860813
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...            0.653739
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...            0.549466
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...            0.528140
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Euba...            0.470304
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.447969
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...            0.444303
# d__Bacteria;p__Chloroflexi;c__Dehalococcoidia;o...            0.439978
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.412306
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...            0.406332

# %% [markdown]
# ## LRP with LOGO

# %%
# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns].apply(pd.to_numeric, errors='coerce')

import tensorflow as tf
tf.compat.v1.disable_eager_execution()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import LeaveOneGroupOut
import innvestigate
from scipy.cluster.hierarchy import linkage, leaves_list

# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns] # .apply(pd.to_numeric, errors='coerce')

# -------------------------------------------------------------
# DEFINE CNN MODEL FUNCTION
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])
    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss='mse')
    return model

### Initialize LOGO
logo = LeaveOneGroupOut()

### Run Neural Network Cross Validation
lrp_cache = pd.DataFrame()
ann_predictions = np.array([])
ann_actuals = np.array([])  # To store actual values for plotting
history_cache = []

# Convert boolean columns to integers (if not already done)
X = X.astype({col: 'int32' for col in X.select_dtypes('bool').columns})

# Specify the target column for single-output regression
target_column = 'ACE-km'  # Replace with your target column name
groups = y['Digester']  # Use Digester as the grouping variable

# -------------------------------------------------------------
# FEATURE SELECTION AND HIERARCHICAL CLUSTERING
# -------------------------------------------------------------
# Select top `num_features` based on variance
num_features = 200  # Change as needed
if X.shape[1] > num_features:
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

# Hierarchical clustering to reorder features
corr = X.corr().fillna(0)  # Compute correlation matrix
Z = linkage(1 - corr, method='average')  # Perform hierarchical clustering
leaf_order = leaves_list(Z)  # Get feature order based on clustering
X = X.iloc[:, leaf_order]  # Reorder features based on clustering

# -------------------------------------------------------------
# PREPROCESSING
# -------------------------------------------------------------
# Pad features to form a square grid for potential 2D inputs
num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))  # Determine grid size
padding = grid_size**2 - num_features_final  # Calculate necessary padding

# Add padding columns with zeros if required
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.values)  # Convert to numpy array after scaling

# -------------------------------------------------------------
# LOGO CROSS-VALIDATION WITH LRP
# -------------------------------------------------------------
for fold, (train_idx, val_idx) in enumerate(logo.split(X_scaled, y[target_column], groups=groups)):
    print(f"Processing Fold {fold + 1}")

    # Define train-test splits
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y.iloc[train_idx][target_column], y.iloc[val_idx][target_column]

    # Ensure target values are numeric and have the correct shape
    y_train = y_train.astype(float).values
    y_val = y_val.astype(float).values

    # Reshape data for neural network input
    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)  # Add channel dimension
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)  # Add channel dimension

    # Build and train the neural network model
    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, batch_size=32, epochs=150, verbose=0, validation_data=(X_val, y_val))

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)
    relevance_scores = analyzer.analyze(X_train)  # Analyze training data

    # Flatten relevance scores and trim to original feature dimensions
    relevance_scores_flat = relevance_scores.mean(axis=0).flatten()[:num_features_final]

    # Store LRP results for original features only
    lrp = pd.DataFrame(relevance_scores_flat, index=X.columns[:num_features_final], columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, lrp], axis=1)

    # Predict and store validation results
    predictions = model.predict(X_val).flatten()
    ann_predictions = np.concatenate([ann_predictions, predictions])
    ann_actuals = np.concatenate([ann_actuals, y_val])  # Store actual values for plotting
    history_cache.append(model.history)

# -------------------------------------------------------------
# EVALUATE MODEL PERFORMANCE
# -------------------------------------------------------------
ann_r2 = r2_score(ann_actuals, ann_predictions)  # R² for regression
ann_mse = mean_squared_error(ann_actuals, ann_predictions)  # MSE for regression

print("\nCross Validation Results:\n")
print("Neural Network R2 Score: {:.5f}".format(ann_r2))
print("Mean Squared Error: {:.5f}".format(ann_mse))

# -------------------------------------------------------------
# SAVE LRP RESULTS
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

lrp_cache.to_csv("lrp_feature_relevance.csv")

# -------------------------------------------------------------
# PLOT PREDICTED VS ACTUAL VALUES
# -------------------------------------------------------------
plt.figure(figsize=(10, 8))
plt.scatter(ann_actuals, ann_predictions, alpha=0.6, edgecolor='k', label="Predictions")
plt.plot([ann_actuals.min(), ann_actuals.max()],
         [ann_actuals.min(), ann_actuals.max()],
         color='red', linestyle='--', label='Ideal Fit')
plt.title("Predicted vs Actual Values (LOGO CV)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.grid(True)
plt.savefig("predicted_vs_actual_plot_logo.png")
plt.show()


# -------------------------------------------------------------
# GENERATE TABLE WITH TOP 10 SELECTED FEATURES
# -------------------------------------------------------------
# Calculate the mean absolute relevance for each feature across all folds
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)

# Sort features by mean absolute relevance
lrp_cache_sorted = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

# Extract the top 10 features
top_10_features = lrp_cache_sorted.head(10)

# Print the table
print("\nTop 10 Features Based on Mean Absolute Relevance Across All Folds:")
print(top_10_features)

# Save the table as a CSV file
top_10_features.to_csv("top_10_features.csv")

# Display the table in a formatted output
from IPython.display import display
display(top_10_features)
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Processing Fold 1
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_47802/3392659725.py:101: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')  # Perform hierarchical clustering
# 2025-01-28 09:40:29.219374: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:29.256594: W tensorflow/c/c_api.cc:304] Operation '{name:'training_46/Adam/dense_46/bias/v/Assign' id:13662 op device:{requested: '', assigned: ''} def:{{{node training_46/Adam/dense_46/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_46/Adam/dense_46/bias/v, training_46/Adam/dense_46/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:29.406558: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:29.489278: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 09:40:29.805801: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_23/mul' id:13470 op device:{requested: '', assigned: ''} def:{{{node loss_23/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_23/mul/x, loss_23/dense_47_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:29.959357: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:32.443027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:32.468057: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_95/Assign' id:13831 op device:{requested: '', assigned: ''} def:{{{node kernel_95/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_95, kernel_95/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:32.608780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:32.662132: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:32.702865: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_138/MaxNeuronSelection_23/Max_grad/range' id:13841 op device:{requested: '', assigned: ''} def:{{{node gradients_138/MaxNeuronSelection_23/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_23/Max"], _has_manual_control_dependencies=true](gradients_138/MaxNeuronSelection_23/Max_grad/range/start, gradients_138/MaxNeuronSelection_23/Max_grad/Size, gradients_138/MaxNeuronSelection_23/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:32.842328: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:32.869173: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_138/MaxNeuronSelection_23/Max_grad/mod' id:13837 op device:{requested: '', assigned: ''} def:{{{node gradients_138/MaxNeuronSelection_23/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_23/Max"], _has_manual_control_dependencies=true](gradients_138/MaxNeuronSelection_23/Max_grad/add, gradients_138/MaxNeuronSelection_23/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:33.010135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:33.036280: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_138/MaxNeuronSelection_23/Max_grad/ones' id:13843 op device:{requested: '', assigned: ''} def:{{{node gradients_138/MaxNeuronSelection_23/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_23/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_138/MaxNeuronSelection_23/Max_grad/Shape_1, gradients_138/MaxNeuronSelection_23/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:33.174131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:33.201524: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_23/Max/reduction_indices' id:13751 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_23/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:33.343321: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:33.371187: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_168/x' id:13858 op device:{requested: '', assigned: ''} def:{{{node mul_168/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:33.519800: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:33.545670: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_92' id:13855 op device:{requested: '', assigned: ''} def:{{{node Const_92}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:33.686693: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:33.717884: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_166' id:13798 op device:{requested: '', assigned: ''} def:{{{node mul_166}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_149, Cast_166)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:33.853826: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:33.899493: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_169/x' id:13882 op device:{requested: '', assigned: ''} def:{{{node mul_169/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:34.040617: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:34.066324: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_93' id:13879 op device:{requested: '', assigned: ''} def:{{{node Const_93}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:34.206133: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:34.239462: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_165' id:13778 op device:{requested: '', assigned: ''} def:{{{node mul_165}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_147, Cast_165)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:34.391105: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:34.429954: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_165' id:13778 op device:{requested: '', assigned: ''} def:{{{node mul_165}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_147, Cast_165)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:34.569437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:34.612213: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_170/x' id:13900 op device:{requested: '', assigned: ''} def:{{{node mul_170/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:34.753519: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:34.779683: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_94' id:13897 op device:{requested: '', assigned: ''} def:{{{node Const_94}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:34.921915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:34.955427: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_164' id:13758 op device:{requested: '', assigned: ''} def:{{{node mul_164}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_145, Cast_164)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:35.125808: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:35.165642: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_164' id:13758 op device:{requested: '', assigned: ''} def:{{{node mul_164}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_145, Cast_164)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:35.341934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:35.383136: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_171/x' id:13917 op device:{requested: '', assigned: ''} def:{{{node mul_171/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:35.523384: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:35.551048: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_95' id:13914 op device:{requested: '', assigned: ''} def:{{{node Const_95}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:35.691877: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 09:40:35.864267: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 09:40:36.047916: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_47/BiasAdd' id:13452 op device:{requested: '', assigned: ''} def:{{{node dense_47/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_47/MatMul, dense_47/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:36.189602: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Processing Fold 2
# 2025-01-28 09:40:36.454411: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:36.489510: W tensorflow/c/c_api.cc:304] Operation '{name:'training_48/Adam/conv2d_48/bias/v/Assign' id:14215 op device:{requested: '', assigned: ''} def:{{{node training_48/Adam/conv2d_48/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_48/Adam/conv2d_48/bias/v, training_48/Adam/conv2d_48/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:36.632256: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:36.700109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 09:40:36.911839: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_24/mul' id:14047 op device:{requested: '', assigned: ''} def:{{{node loss_24/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_24/mul/x, loss_24/dense_49_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:37.058209: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:39.554392: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:39.583451: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_97/Assign' id:14368 op device:{requested: '', assigned: ''} def:{{{node kernel_97/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_97, kernel_97/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:39.732752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:39.786246: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:39.825109: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_144/MaxNeuronSelection_24/Max_grad/range' id:14418 op device:{requested: '', assigned: ''} def:{{{node gradients_144/MaxNeuronSelection_24/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_24/Max"], _has_manual_control_dependencies=true](gradients_144/MaxNeuronSelection_24/Max_grad/range/start, gradients_144/MaxNeuronSelection_24/Max_grad/Size, gradients_144/MaxNeuronSelection_24/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:39.969816: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:39.996432: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_144/MaxNeuronSelection_24/Max_grad/mod' id:14414 op device:{requested: '', assigned: ''} def:{{{node gradients_144/MaxNeuronSelection_24/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_24/Max"], _has_manual_control_dependencies=true](gradients_144/MaxNeuronSelection_24/Max_grad/add, gradients_144/MaxNeuronSelection_24/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:40.195265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:40.227069: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_144/MaxNeuronSelection_24/Max_grad/ones' id:14420 op device:{requested: '', assigned: ''} def:{{{node gradients_144/MaxNeuronSelection_24/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_24/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_144/MaxNeuronSelection_24/Max_grad/Shape_1, gradients_144/MaxNeuronSelection_24/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:40.399818: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:40.429678: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_24/Max/reduction_indices' id:14328 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_24/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:40.577416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:40.605144: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_176/x' id:14435 op device:{requested: '', assigned: ''} def:{{{node mul_176/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:40.751614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:40.777920: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_96' id:14432 op device:{requested: '', assigned: ''} def:{{{node Const_96}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:40.930584: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:40.962774: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_174' id:14375 op device:{requested: '', assigned: ''} def:{{{node mul_174}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_157, Cast_174)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:41.114765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:41.161447: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_177/x' id:14459 op device:{requested: '', assigned: ''} def:{{{node mul_177/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:41.308136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:41.334483: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_97' id:14456 op device:{requested: '', assigned: ''} def:{{{node Const_97}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:41.494686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:41.528443: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_173' id:14355 op device:{requested: '', assigned: ''} def:{{{node mul_173}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_155, Cast_173)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:41.695520: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:41.745869: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_173' id:14355 op device:{requested: '', assigned: ''} def:{{{node mul_173}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_155, Cast_173)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:41.890823: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:41.930403: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_178/x' id:14477 op device:{requested: '', assigned: ''} def:{{{node mul_178/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:42.074109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:42.100566: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_98' id:14474 op device:{requested: '', assigned: ''} def:{{{node Const_98}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:42.246588: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:42.280150: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_172' id:14335 op device:{requested: '', assigned: ''} def:{{{node mul_172}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_153, Cast_172)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:42.426513: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:42.465113: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_172' id:14335 op device:{requested: '', assigned: ''} def:{{{node mul_172}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_153, Cast_172)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:42.617600: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:42.658290: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_179/x' id:14494 op device:{requested: '', assigned: ''} def:{{{node mul_179/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:42.803039: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:42.830089: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_99' id:14491 op device:{requested: '', assigned: ''} def:{{{node Const_99}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:42.981559: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 09:40:43.158805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 09:40:43.315964: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_49/BiasAdd' id:14029 op device:{requested: '', assigned: ''} def:{{{node dense_49/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_49/MatMul, dense_49/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:43.467375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Processing Fold 3
# 2025-01-28 09:40:43.745044: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:43.780996: W tensorflow/c/c_api.cc:304] Operation '{name:'training_50/Adam/conv2d_50/bias/v/Assign' id:14792 op device:{requested: '', assigned: ''} def:{{{node training_50/Adam/conv2d_50/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_50/Adam/conv2d_50/bias/v, training_50/Adam/conv2d_50/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:43.932113: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:44.002631: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 09:40:44.207942: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_25/mul' id:14624 op device:{requested: '', assigned: ''} def:{{{node loss_25/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_25/mul/x, loss_25/dense_51_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:44.363125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:46.657299: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:46.684228: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_103/Assign' id:14985 op device:{requested: '', assigned: ''} def:{{{node kernel_103/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_103, kernel_103/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:46.832614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:46.888341: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:46.927912: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_150/MaxNeuronSelection_25/Max_grad/range' id:14995 op device:{requested: '', assigned: ''} def:{{{node gradients_150/MaxNeuronSelection_25/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_25/Max"], _has_manual_control_dependencies=true](gradients_150/MaxNeuronSelection_25/Max_grad/range/start, gradients_150/MaxNeuronSelection_25/Max_grad/Size, gradients_150/MaxNeuronSelection_25/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:47.077330: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:47.106150: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_150/MaxNeuronSelection_25/Max_grad/mod' id:14991 op device:{requested: '', assigned: ''} def:{{{node gradients_150/MaxNeuronSelection_25/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_25/Max"], _has_manual_control_dependencies=true](gradients_150/MaxNeuronSelection_25/Max_grad/add, gradients_150/MaxNeuronSelection_25/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:47.256572: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:47.283820: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_150/MaxNeuronSelection_25/Max_grad/ones' id:14997 op device:{requested: '', assigned: ''} def:{{{node gradients_150/MaxNeuronSelection_25/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_25/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_150/MaxNeuronSelection_25/Max_grad/Shape_1, gradients_150/MaxNeuronSelection_25/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:47.470126: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:47.498138: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_25/Max/reduction_indices' id:14905 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_25/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:47.649283: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:47.678976: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_184/x' id:15012 op device:{requested: '', assigned: ''} def:{{{node mul_184/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:47.833787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:47.863421: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_100' id:15009 op device:{requested: '', assigned: ''} def:{{{node Const_100}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:48.025769: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:48.057865: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_182' id:14952 op device:{requested: '', assigned: ''} def:{{{node mul_182}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_165, Cast_182)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:48.216387: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:48.263781: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_185/x' id:15036 op device:{requested: '', assigned: ''} def:{{{node mul_185/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:48.415887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:48.443409: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_101' id:15033 op device:{requested: '', assigned: ''} def:{{{node Const_101}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:48.599046: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:48.633202: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_181' id:14932 op device:{requested: '', assigned: ''} def:{{{node mul_181}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_163, Cast_181)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:48.790682: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:48.831894: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_181' id:14932 op device:{requested: '', assigned: ''} def:{{{node mul_181}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_163, Cast_181)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:48.987606: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:49.031009: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_186/x' id:15054 op device:{requested: '', assigned: ''} def:{{{node mul_186/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:49.184645: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:49.213310: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_102' id:15051 op device:{requested: '', assigned: ''} def:{{{node Const_102}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:49.365030: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:49.397636: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_180' id:14912 op device:{requested: '', assigned: ''} def:{{{node mul_180}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_161, Cast_180)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:49.550741: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:49.591088: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_180' id:14912 op device:{requested: '', assigned: ''} def:{{{node mul_180}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_161, Cast_180)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:49.747496: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:49.789371: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_187/x' id:15071 op device:{requested: '', assigned: ''} def:{{{node mul_187/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:49.939474: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 09:40:49.967390: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_103' id:15068 op device:{requested: '', assigned: ''} def:{{{node Const_103}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 09:40:50.123878: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 09:40:50.314060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 09:40:50.532193: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_51/BiasAdd' id:14606 op device:{requested: '', assigned: ''} def:{{{node dense_51/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_51/MatMul, dense_51/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl... -2.878762  0.258980
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.031250  0.463899
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  2.330997  0.106721
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.684978  0.889538
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B... -0.398626  0.345196
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__... -0.048339  0.258638
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  2.681814  0.093537
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.218236  0.460574
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.304220  0.818807
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.349945  0.731700
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.263673  0.493575
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.349473  0.872049
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.202373 -0.074286
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.220034  0.076625
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.306500  0.209736
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.076294 -0.642567
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.161882 -0.059008
#
#                                                       Fold_4    Fold_5  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.297686 -0.106627
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.334276  0.097547
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.293806  0.275773
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.238850  0.107925
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.404373  0.081734
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.121964  0.342790
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.161282  0.334546
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.324950  0.311132
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.054708  0.291667
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.102965  0.298807
#
#                                                       Fold_6    Fold_7  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.154812  0.222166
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.249077  0.337158
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.284927  0.535165
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.092016  0.240456
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.217964  0.540437
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.288415  0.147716
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.199100  0.182080
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.134733  0.467104
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.111399  0.055673
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.209238  0.117779
#
#                                                       Fold_8    Fold_9  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.204020  0.258014
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.328544  0.345898
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.345162  0.444213
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.248606  0.278931
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.374354  0.501578
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.180176  0.141834
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.247117  0.170597
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.299221  0.368406
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.064046  0.057321
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.176762  0.141595
#
#                                                      Fold_10   Fold_11  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.116087  0.232818
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o... -0.832183  0.380865
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;... -1.222891  0.470128
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl... -0.391238  0.281429
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o... -0.288786  0.514437
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  1.206466  0.115164
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  1.322878  0.167292
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.340225  0.399797
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  3.747216  0.061305
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.588730  0.135839
#
#                                                      Fold_12   Fold_13  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.238322  0.182469
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.304743  0.247141
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.374420  0.373719
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.288794  0.204147
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.412608  0.350181
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.121227  0.219628
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.173232  0.301709
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.320720  0.330951
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.060697  0.060575
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.138693  0.165505
#
#                                                      Fold_14   Fold_15  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.231296  0.397018
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.314599  0.338136
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.439293  0.325171
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.261893  0.313945
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.389251  0.373578
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.116641  0.117510
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.205509  0.239110
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.391326  0.375983
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.045392  0.155838
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.106268  0.122447
#
#                                                      Fold_16   Fold_17  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.260626  0.116799
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.449976  0.200115
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.536855  0.170536
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.289810  0.125540
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.654999  0.253705
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.060285  0.188843
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.154473  0.237872
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.422115  0.161862
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__... -0.018383  0.081575
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.106960  0.180488
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...            0.532825
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.476121
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...            0.448191
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...            0.403254
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.393037
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...            0.337946
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...            0.331554
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.328255
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...            0.327313
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...            0.310462
#                                                       Fold_0    Fold_1  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie... -5.737488  0.155795
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o... -2.444042  0.242850
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.446543  0.447188
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl... -2.878762  0.258980
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.031250  0.463899
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  2.330997  0.106721
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.684978  0.889538
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B... -0.398626  0.345196
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__... -0.048339  0.258638
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  2.681814  0.093537
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.218236  0.460574
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.304220  0.818807
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.349945  0.731700
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.263673  0.493575
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.349473  0.872049
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.202373 -0.074286
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.220034  0.076625
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.306500  0.209736
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.076294 -0.642567
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.161882 -0.059008
#
#                                                       Fold_4    Fold_5  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.297686 -0.106627
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.334276  0.097547
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.293806  0.275773
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.238850  0.107925
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.404373  0.081734
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.121964  0.342790
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.161282  0.334546
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.324950  0.311132
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.054708  0.291667
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.102965  0.298807
#
#                                                       Fold_6    Fold_7  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.154812  0.222166
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.249077  0.337158
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.284927  0.535165
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.092016  0.240456
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.217964  0.540437
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.288415  0.147716
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.199100  0.182080
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.134733  0.467104
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.111399  0.055673
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.209238  0.117779
#
#                                                       Fold_8    Fold_9  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.204020  0.258014
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.328544  0.345898
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.345162  0.444213
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.248606  0.278931
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.374354  0.501578
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.180176  0.141834
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.247117  0.170597
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.299221  0.368406
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.064046  0.057321
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.176762  0.141595
#
#                                                      Fold_10   Fold_11  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.116087  0.232818
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o... -0.832183  0.380865
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;... -1.222891  0.470128
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl... -0.391238  0.281429
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o... -0.288786  0.514437
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  1.206466  0.115164
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  1.322878  0.167292
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.340225  0.399797
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  3.747216  0.061305
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.588730  0.135839
#
#                                                      Fold_12   Fold_13  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.238322  0.182469
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.304743  0.247141
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.374420  0.373719
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.288794  0.204147
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.412608  0.350181
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.121227  0.219628
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.173232  0.301709
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.320720  0.330951
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.060697  0.060575
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.138693  0.165505
#
#                                                      Fold_14   Fold_15  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.231296  0.397018
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.314599  0.338136
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.439293  0.325171
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.261893  0.313945
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.389251  0.373578
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.116641  0.117510
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.205509  0.239110
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.391326  0.375983
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.045392  0.155838
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.106268  0.122447
#
#                                                      Fold_16   Fold_17  \
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.260626  0.116799
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.449976  0.200115
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.536855  0.170536
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.289810  0.125540
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.654999  0.253705
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.060285  0.188843
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.154473  0.237872
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.422115  0.161862
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__... -0.018383  0.081575
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.106960  0.180488
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...            0.532825
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.476121
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...            0.448191
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...            0.403254
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.393037
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...            0.337946
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...            0.331554
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.328255
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...            0.327313
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...            0.310462

# %% [markdown]
# ## LRP with extra changes

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from scipy.cluster.hierarchy import linkage, leaves_list
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# tf.compat.v1.disable_eager_execution()  # For innvestigate compatibility if needed

# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns].apply(pd.to_numeric, errors='coerce')

print(f"Features (X): {X.shape}")
print(f"Targets (y): {y.shape}")

num_samples = X.shape[0]
num_folds = 5
num_features = 500  # number of features to select from LRP or just a chosen subset
chunks = np.ceil(np.linspace(0,num_samples, num=num_folds+1)).astype(int)

# # -------------------------------------------------------------
# # PREPROCESSING AND ARRANGING FEATURES FOR CNN
# # -------------------------------------------------------------
# # 1. Feature Selection (Optional): If you want to reduce features before CNN,
# #    you can select top features based on variance or another criterion.
# if X.shape[1] > num_features:
#     # For demonstration, select top `num_features` by variance or mean abundance
#     feature_variances = X.var().sort_values(ascending=False)
#     top_features = feature_variances.index[:num_features]
#     X = X[top_features]

# # 2. Compute correlation matrix and cluster features
# corr = X.corr().fillna(0)
# # Perform hierarchical clustering on correlation
# Z = linkage(1 - corr, method='average')  # Using 1 - corr as a distance metric
# leaf_order = leaves_list(Z)  # Order of columns (features) after clustering

# # Reorder X columns based on cluster order
# X = X.iloc[:, leaf_order]

# # 3. Reshape features into a 2D grid
# # For CNN, we need a 2D (height x width) structure.
# # We'll try to form a square grid if possible.
# num_features_final = X.shape[1]
# grid_size = int(np.ceil(np.sqrt(num_features_final)))  # e.g., if we have 500 features, sqrt(500) ~ 22.36, so 23x23 grid
# padding = grid_size**2 - num_features_final

# # Pad columns with zeros if needed
# if padding > 0:
#     extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
#     X = pd.concat([X, extra_cols], axis=1)

# # After padding, reshape each sample into a (grid_size, grid_size, 1) "image"
# # We'll do this inside the cross-validation loop.

# # -------------------------------------------------------------
# # DEFINE CNN MODEL
# # -------------------------------------------------------------
# def build_cnn_model(input_shape):
#     # A simple CNN model for regression
#     model = Sequential()
#     model.add(Conv2D(16, kernel_size=(3,3), activation='relu', input_shape=input_shape))
#     model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
#     model.add(Flatten())
#     model.add(Dense(64, activation='relu'))
#     # Assuming you want to predict a single target column at a time;
#     # If multiple targets, change units to number of targets.
#     model.add(Dense(1, activation='linear'))
#     model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
#     return model


# # -------------------------------------------------------------
# # CROSS-VALIDATION AND TRAINING CNN
# # -------------------------------------------------------------
# # We'll pick one target column (e.g., 'ACE-km') for demonstration.
# target_column = 'ACE-km'
# if target_column not in y.columns:
#     raise ValueError(f"Target column {target_column} not found in y.")

# all_y_true = []
# all_y_pred = []

# kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# X_values = X.values
# y_values = y[target_column].values.astype(float)

# # Scale features
# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X_values)

# for fold, (train_idx, val_idx) in enumerate(kf.split(X_scaled)):
#     X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
#     y_train, y_val = y_values[train_idx], y_values[val_idx]

#     # Reshape data into 2D grid
#     X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)
#     X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)

#     # Build and train CNN model
#     model = build_cnn_model((grid_size, grid_size, 1))
#     model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1, validation_data=(X_val, y_val))

#     # Predict
#     preds = model.predict(X_val).flatten()
#     all_y_true.extend(y_val)
#     all_y_pred.extend(preds)

# # Evaluate Performance
# all_y_true = np.array(all_y_true)
# all_y_pred = np.array(all_y_pred)

# r2 = r2_score(all_y_true, all_y_pred)
# mse = mean_squared_error(all_y_true, all_y_pred)
# print(f"R2 Score: {r2:.4f}")
# print(f"MSE: {mse:.4f}")
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Features (X): (54, 1087)
# Targets (y): (54, 12)

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()  # Ensure graph mode for innvestigate

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from scipy.cluster.hierarchy import linkage, leaves_list
import innvestigate
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers.legacy import Adam

# -------------------------------------------------------------
# DEFINE CNN MODEL FUNCTION
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = Sequential([
        Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        Conv2D(32, kernel_size=(3, 3), activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

# -------------------------------------------------------------
# FEATURE SELECTION AND HIERARCHICAL CLUSTERING
# -------------------------------------------------------------
# Dummy data setup (replace with actual data loading)
X = pd.DataFrame(np.random.rand(1000, 1200))  # Replace with your dataset
y = pd.DataFrame({"ACE-km": np.random.rand(1000)})  # Replace with your target column

# Select top features
num_features = 1086  # Number of features to keep
if X.shape[1] > num_features:
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

# Perform hierarchical clustering
corr = X.corr().fillna(0)
Z = linkage(1 - corr, method='average')
leaf_order = leaves_list(Z)
X = X.iloc[:, leaf_order]

# Pad to square grid
num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))
padding = grid_size**2 - num_features_final
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# Scale features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.values)

# -------------------------------------------------------------
# CROSS-VALIDATION AND LRP
# -------------------------------------------------------------
num_folds = 5
chunk_size = len(X_scaled) // num_folds
chunks = [i * chunk_size for i in range(num_folds)] + [len(X_scaled)]

lrp_cache = pd.DataFrame()
ann_predictions = np.array([])
ann_actuals = np.array([])

for fold in range(num_folds):
    # Reset session
    tf.keras.backend.clear_session()

    # Split train and validation data
    X_val = X_scaled[chunks[fold]:chunks[fold + 1]]
    y_val = y.iloc[chunks[fold]:chunks[fold + 1]]["ACE-km"]

    X_train = np.delete(X_scaled, np.arange(chunks[fold], chunks[fold + 1]), axis=0)
    y_train = y.drop(y_val.index)["ACE-km"]

    # Convert to appropriate shape
    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)

    y_train = y_train.values.astype(float)
    y_val = y_val.values.astype(float)

    # Train model
    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, batch_size=32, epochs=30, verbose=0, validation_data=(X_val, y_val))

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)
    relevance_scores = analyzer.analyze(X_train)  # LRP on training data

    # Flatten relevance scores and map to original features
    relevance_scores_flat = relevance_scores.mean(axis=0).flatten()[:num_features_final]
    lrp = pd.DataFrame(relevance_scores_flat, index=X.columns[:num_features_final], columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, lrp], axis=1)

    # Collect predictions and actual values
    predictions = model.predict(X_val).flatten()
    ann_predictions = np.concatenate([ann_predictions, predictions])
    ann_actuals = np.concatenate([ann_actuals, y_val])

# -------------------------------------------------------------
# EVALUATE PERFORMANCE
# -------------------------------------------------------------
r2 = r2_score(ann_actuals, ann_predictions)
mse = mean_squared_error(ann_actuals, ann_predictions)

print("\nCross Validation Results:")
print(f"R2 Score: {r2:.4f}")
print(f"Mean Squared Error: {mse:.4f}")

# -------------------------------------------------------------
# SAVE LRP RESULTS
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

lrp_cache.to_csv("lrp_feature_relevance.csv")

# -------------------------------------------------------------
# PLOT PREDICTED VS ACTUAL VALUES
# -------------------------------------------------------------
plt.figure(figsize=(10, 8))
plt.scatter(ann_actuals, ann_predictions, alpha=0.6, edgecolor='k', label="Predictions")
plt.plot([ann_actuals.min(), ann_actuals.max()],
         [ann_actuals.min(), ann_actuals.max()],
         color='red', linestyle='--', label='Ideal Fit')
plt.title("Predicted vs Actual Values (All Folds)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.grid(True)
plt.savefig("predicted_vs_actual_plot.png")
plt.show()
# Out:
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_66061/3401667258.py:45: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')
# 2025-01-28 11:09:10.848597: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-01-28 11:09:10.848616: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-01-28 11:09:10.853733: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2025-01-28 11:09:10.856427: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:10.869362: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_1/kernel/v/Assign' id:316 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_1/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_1/kernel/v, training/Adam/dense_1/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:10.873535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:10.920362: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:09:11.255275: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:11.259437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.320986: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.325060: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_3/Assign' id:480 op device:{requested: '', assigned: ''} def:{{{node kernel_3/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_3, kernel_3/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.330124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.354675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.369323: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.374532: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.377291: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.382122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.385161: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.390056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.393966: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.398972: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.403406: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.408485: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.411962: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.427894: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.463113: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.473921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.492225: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.497222: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.500707: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.506098: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.516210: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.521845: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.537319: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.542656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.559901: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.565225: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.568532: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.574027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.582781: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.588220: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.603233: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.608707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.624203: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.629815: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:18.633268: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:18.638553: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:09:18.652243: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:09:19.114308: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:19.120458: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:19.315720: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-01-28 11:09:19.315741: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-01-28 11:09:19.324149: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:19.337073: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense/bias/v/Assign' id:311 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense/bias/v, training/Adam/dense/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:19.351284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:19.409238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:09:19.741735: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:19.745924: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.302619: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.306521: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_2/Assign' id:460 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.311635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.337028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.352053: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.357195: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.359747: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.365045: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.367737: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.372627: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.376377: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.381143: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.385360: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.390732: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.393988: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.399197: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.407261: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.412412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.429927: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.435455: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.438665: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.444019: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.453889: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.459426: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.474463: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.479969: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.496294: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.501622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.505103: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.510163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.519345: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.525297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.540444: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.545947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.562531: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.568007: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.571176: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.576584: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.590058: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:09:26.727098: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.732822: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.877188: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-01-28 11:09:26.877209: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-01-28 11:09:26.885019: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.898499: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/conv2d/bias/v/Assign' id:287 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d/bias/v, training/Adam/conv2d/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:26.902636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:26.955800: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:09:27.284745: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:27.288872: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:33.982707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:33.986740: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_2/Assign' id:460 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:33.991916: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.017828: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.032855: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.037715: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.040331: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.045890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.048734: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.053665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.057605: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.062680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.066611: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.071865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.074918: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.079994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.088582: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.093765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.109931: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.115276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.118707: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.123906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.133711: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.139056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.154086: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.159357: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.174890: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.179983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.183367: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.188326: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.197067: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.202972: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.217094: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.222721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.238453: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.244119: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.247642: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:34.253008: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:34.266467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:09:34.411781: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ...
# 2025-01-28 11:09:42.255577: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:42.302315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2025-01-28 11:09:42.623998: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:42.628284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.623921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.627727: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_2/Assign' id:460 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.632834: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.658393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.673900: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.679424: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.682174: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.687523: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.690513: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.695490: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.699382: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.704616: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.708752: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.713656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.717092: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.722302: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.730917: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.736568: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.754918: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.760653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.764047: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.769178: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.779520: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.785196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.800861: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.806190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.823793: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.829182: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.832715: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.838441: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.847812: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.853660: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.869737: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.875245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.890431: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.895835: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.898993: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:49.904387: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-28 11:09:49.918285: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-28 11:09:50.057187: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-01-28 11:09:50.062877: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Cross Validation Results:
# R2 Score: -0.2399
# Mean Squared Error: 0.1053
#
# Top 10 Features by Relevance:
#        Fold_0    Fold_1    Fold_2    Fold_3    Fold_4  Mean_Abs_Relevance
# 457  0.000598  0.000753  0.000671  0.000693  0.000616            0.000666
# 808  0.000696  0.000682  0.000636  0.000621  0.000682            0.000663
# 266  0.000653  0.000661  0.000598  0.000635  0.000760            0.000661
# 797  0.000628  0.000710  0.000637  0.000686  0.000626            0.000657
# 439  0.000619  0.000657  0.000601  0.000676  0.000725            0.000656
# 519  0.000617  0.000638  0.000635  0.000657  0.000730            0.000655
# 278  0.000598  0.000641  0.000623  0.000639  0.000772            0.000655
# 724  0.000637  0.000653  0.000644  0.000662  0.000674            0.000654
# 672  0.000575  0.000658  0.000629  0.000651  0.000738            0.000650
# 646  0.000615  0.000594  0.000641  0.000622  0.000778            0.000650
