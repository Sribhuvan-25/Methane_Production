# %%
import numpy as np # Version 1.16.0

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
import pandas as pd
import keras # Version 2.2.4
from sklearn.metrics import r2_score
import innvestigate as inn # Version 1.0.8
print("tensorflow version:", tf.__version__)
print("keras version:", keras.__version__)
# Out:
# tensorflow version: 2.13.0
# keras version: 2.13.1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from scipy.cluster.hierarchy import linkage, leaves_list
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# tf.compat.v1.disable_eager_execution()  # For innvestigate compatibility if needed

# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns].apply(pd.to_numeric, errors='coerce')

print(f"Features (X): {X.shape}")
print(f"Targets (y): {y.shape}")

num_samples = X.shape[0]
num_folds = 5
num_features = 500  # number of features to select from LRP or just a chosen subset
chunks = np.ceil(np.linspace(0,num_samples, num=num_folds+1)).astype(int)

# -------------------------------------------------------------
# PREPROCESSING AND ARRANGING FEATURES FOR CNN
# -------------------------------------------------------------
# 1. Feature Selection (Optional): If you want to reduce features before CNN,
#    you can select top features based on variance or another criterion.
if X.shape[1] > num_features:
    # For demonstration, select top `num_features` by variance or mean abundance
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

# 2. Compute correlation matrix and cluster features
corr = X.corr().fillna(0)
# Perform hierarchical clustering on correlation
Z = linkage(1 - corr, method='average')  # Using 1 - corr as a distance metric
leaf_order = leaves_list(Z)  # Order of columns (features) after clustering

# Reorder X columns based on cluster order
X = X.iloc[:, leaf_order]

# 3. Reshape features into a 2D grid
# For CNN, we need a 2D (height x width) structure.
# We'll try to form a square grid if possible.
num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))  # e.g., if we have 500 features, sqrt(500) ~ 22.36, so 23x23 grid
padding = grid_size**2 - num_features_final

# Pad columns with zeros if needed
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# After padding, reshape each sample into a (grid_size, grid_size, 1) "image"
# We'll do this inside the cross-validation loop.

# -------------------------------------------------------------
# DEFINE CNN MODEL
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    # A simple CNN model for regression
    model = Sequential()
    model.add(Conv2D(16, kernel_size=(3,3), activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    # Assuming you want to predict a single target column at a time;
    # If multiple targets, change units to number of targets.
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model


# -------------------------------------------------------------
# CROSS-VALIDATION AND TRAINING CNN
# -------------------------------------------------------------
# We'll pick one target column (e.g., 'ACE-km') for demonstration.
target_column = 'ACE-km'
if target_column not in y.columns:
    raise ValueError(f"Target column {target_column} not found in y.")

all_y_true = []
all_y_pred = []

kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

X_values = X.values
y_values = y[target_column].values.astype(float)

# Scale features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_values)

for fold, (train_idx, val_idx) in enumerate(kf.split(X_scaled)):
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y_values[train_idx], y_values[val_idx]

    # Reshape data into 2D grid
    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)

    # Build and train CNN model
    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1, validation_data=(X_val, y_val))

    # Predict
    preds = model.predict(X_val).flatten()
    all_y_true.extend(y_val)
    all_y_pred.extend(preds)

# Evaluate Performance
all_y_true = np.array(all_y_true)
all_y_pred = np.array(all_y_pred)

r2 = r2_score(all_y_true, all_y_pred)
mse = mean_squared_error(all_y_true, all_y_pred)
print(f"R2 Score: {r2:.4f}")
print(f"MSE: {mse:.4f}")
# Out:
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_60065/3142300851.py:59: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')  # Using 1 - corr as a distance metric
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Features (X): (54, 1087)
# Targets (y): (54, 12)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 126
#     123 X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)
#     125 # Build and train CNN model
# --> 126 model = build_cnn_model((grid_size, grid_size, 1))
#     127 model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1, validation_data=(X_val, y_val))
#     129 # Predict
#
# Cell In[2], line 93, in build_cnn_model(input_shape)
#      90 # Assuming you want to predict a single target column at a time;
#      91 # If multiple targets, change units to number of targets.
#      92 model.add(Dense(1, activation='linear'))
# ---> 93 model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
#      94 return model
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:321, in Model.compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, distribute, **kwargs)
#     314     if self.run_eagerly:
#     315         raise ValueError(
#     316             "Session keyword arguments are not supported "
#     317             "when `run_eagerly=True`. You passed the following "
#     318             "Session arguments: %s" % (self._function_kwargs,)
#     319         )
# --> 321 self._set_optimizer(optimizer)
#     322 is_any_keras_optimizer_v1 = any(
#     323     (
#     324         isinstance(opt, optimizer_v1.Optimizer)
#    (...)
#     327     for opt in tf.nest.flatten(self.optimizer)
#     328 )
#     330 if (
#     331     is_any_keras_optimizer_v1
#     332     and tf.compat.v1.executing_eagerly_outside_functions()
#     333 ):
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:1473, in Model._set_optimizer(self, optimizer)
#    1471     self.optimizer = [optimizers.get(opt) for opt in optimizer]
#    1472 else:
# -> 1473     self.optimizer = optimizers.get(optimizer)
#    1475 if self._dtype_policy.name == "mixed_float16" and not isinstance(
#    1476     self.optimizer, loss_scale_optimizer.LossScaleOptimizer
#    1477 ):
#    1478     if isinstance(self.optimizer, list):
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/optimizers/__init__.py:298, in get(identifier, **kwargs)
#     291         optimizer_name = identifier.__class__.__name__
#     292         logging.warning(
#     293             "There is a known slowdown when using v2.11+ Keras optimizers "
#     294             "on M1/M2 Macs. Falling back to the "
#     295             "legacy Keras optimizer, i.e., "
#     296             f"`tf.keras.optimizers.legacy.{optimizer_name}`."
#     297         )
# --> 298         return convert_to_legacy_optimizer(identifier)
#     300 # Wrap legacy TF optimizer instances
#     301 elif isinstance(identifier, tf.compat.v1.train.Optimizer):
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/optimizers/__init__.py:222, in convert_to_legacy_optimizer(optimizer)
#     216     raise ValueError(
#     217         "`convert_to_legacy_optimizer` should only be called "
#     218         "on instances of `tf.keras.optimizers.Optimizer`, but "
#     219         f"received {optimizer} of type {type(optimizer)}."
#     220     )
#     221 optimizer_name = optimizer.__class__.__name__.lower()
# --> 222 config = optimizer.get_config()
#     223 # Remove fields that only exist in experimental optimizer.
#     224 keys_to_remove = [
#     225     "weight_decay",
#     226     "use_ema",
#    (...)
#     230     "is_legacy_optimizer",
#     231 ]
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/optimizers/adam.py:211, in Adam.get_config(self)
#     206 def get_config(self):
#     207     config = super().get_config()
#     209     config.update(
#     210         {
# --> 211             "learning_rate": self._serialize_hyperparameter(
#     212                 self._learning_rate
#     213             ),
#     214             "beta_1": self.beta_1,
#     215             "beta_2": self.beta_2,
#     216             "epsilon": self.epsilon,
#     217             "amsgrad": self.amsgrad,
#     218         }
#     219     )
#     220     return config
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py:736, in _BaseOptimizer._serialize_hyperparameter(self, hyperparameter)
#     734     return learning_rate_schedule.serialize(hyperparameter)
#     735 if isinstance(hyperparameter, tf.Variable):
# --> 736     return hyperparameter.numpy()
#     737 if callable(hyperparameter):
#     738     return hyperparameter()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 if context.executing_eagerly():
#     688   return self.read_value().numpy()
# --> 689 raise NotImplementedError(
#     690     "numpy() is only available when eager execution is enabled.")
#
# NotImplementedError: numpy() is only available when eager execution is enabled.

# %% [markdown]
# ## With LRP (Different LRP Implementation)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from scipy.cluster.hierarchy import linkage, leaves_list
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers.legacy import Adam  # Use legacy optimizer for M1/M2 Macs
import innvestigate  # For LRP

# -------------------------------------------------------------
# DISABLE EAGER EXECUTION
# -------------------------------------------------------------
tf.compat.v1.disable_eager_execution()

# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')
X = df.drop(columns=target_columns)
y = df[target_columns].apply(pd.to_numeric, errors='coerce')

# Feature Preprocessing
num_features = 500
if X.shape[1] > num_features:
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

corr = X.corr().fillna(0)
Z = linkage(1 - corr, method='average')
leaf_order = leaves_list(Z)
X = X.iloc[:, leaf_order]

num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))
padding = grid_size**2 - num_features_final
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# -------------------------------------------------------------
# DEFINE CNN MODEL
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = Sequential([
        Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        Conv2D(32, kernel_size=(3, 3), activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

# -------------------------------------------------------------
# CROSS-VALIDATION WITH LRP
# -------------------------------------------------------------
target_column = 'ACE-km'
all_y_true, all_y_pred = [], []
lrp_cache = pd.DataFrame(index=X.columns)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
X_values = X.values
y_values = y[target_column].values.astype(float)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_values)

for fold, (train_idx, val_idx) in enumerate(kf.split(X_scaled)):
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y_values[train_idx], y_values[val_idx]

    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)

    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1, validation_data=(X_val, y_val))

    preds = model.predict(X_val).flatten()
    all_y_true.extend(y_val)
    all_y_pred.extend(preds)

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z", model)

    # Ensure the input shape for LRP matches the model's input
    relevance_scores = analyzer.analyze(X_train).mean(axis=0)
    relevance_df = pd.DataFrame(relevance_scores.flatten(), index=X.columns, columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, relevance_df], axis=1)

# -------------------------------------------------------------
# EVALUATE PERFORMANCE
# -------------------------------------------------------------
all_y_true = np.array(all_y_true)
all_y_pred = np.array(all_y_pred)

r2 = r2_score(all_y_true, all_y_pred)
mse = mean_squared_error(all_y_true, all_y_pred)
print(f"R2 Score: {r2:.4f}")
print(f"MSE: {mse:.4f}")

# -------------------------------------------------------------
# LRP RESULTS
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

lrp_cache.to_csv("lrp_feature_relevance.csv")
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Train on 43 samples, validate on 11 samples
# Epoch 1/30
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_60134/3076364491.py:46: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')
# 2024-12-16 15:29:21.683865: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 15:29:21.683882: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 15:29:21.694195: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2024-12-16 15:29:21.698857: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:21.718002: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/conv2d_105/bias/v/Assign' id:407 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d_105/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d_105/bias/v, training/Adam/conv2d_105/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:21.724463: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 32/43 [=====================>........] - ETA: 0s - loss: 328.6580
# 2024-12-16 15:29:21.782307: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 9ms/sample - loss: 327.3038 - val_loss: 105.0337
# Epoch 2/30
# 43/43 [==============================] - 0s 833us/sample - loss: 266.0707 - val_loss: 66.9466
# Epoch 3/30
# 43/43 [==============================] - 0s 406us/sample - loss: 194.8380 - val_loss: 47.7080
# Epoch 4/30
# 43/43 [==============================] - 0s 404us/sample - loss: 120.0106 - val_loss: 104.1501
# Epoch 5/30
# 43/43 [==============================] - 0s 435us/sample - loss: 117.5736 - val_loss: 168.2933
# Epoch 6/30
# 43/43 [==============================] - 0s 416us/sample - loss: 139.8943 - val_loss: 129.9536
# Epoch 7/30
# 43/43 [==============================] - 0s 435us/sample - loss: 111.9772 - val_loss: 77.5818
# Epoch 8/30
# 43/43 [==============================] - 0s 396us/sample - loss: 85.3044 - val_loss: 51.5491
# Epoch 9/30
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 15:29:22.019215: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:225 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_27_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.028210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 473us/sample - loss: 78.9780 - val_loss: 42.9581
# Epoch 10/30
# 43/43 [==============================] - 0s 410us/sample - loss: 77.3628 - val_loss: 40.4810
# Epoch 11/30
# 43/43 [==============================] - 0s 424us/sample - loss: 72.5615 - val_loss: 39.5274
# Epoch 12/30
# 43/43 [==============================] - 0s 407us/sample - loss: 62.4837 - val_loss: 39.1985
# Epoch 13/30
# 43/43 [==============================] - 0s 1ms/sample - loss: 52.0518 - val_loss: 39.6813
# Epoch 14/30
# 43/43 [==============================] - 0s 429us/sample - loss: 46.5150 - val_loss: 40.4851
# Epoch 15/30
# 43/43 [==============================] - 0s 401us/sample - loss: 42.2993 - val_loss: 39.2432
# Epoch 16/30
# 43/43 [==============================] - 0s 405us/sample - loss: 39.6692 - val_loss: 36.1157
# Epoch 17/30
# 43/43 [==============================] - 0s 419us/sample - loss: 36.2625 - val_loss: 33.2448
# Epoch 18/30
# 43/43 [==============================] - 0s 417us/sample - loss: 33.5338 - val_loss: 31.9300
# Epoch 19/30
# 43/43 [==============================] - 0s 397us/sample - loss: 30.8116 - val_loss: 31.8251
# Epoch 20/30
# 43/43 [==============================] - 0s 407us/sample - loss: 29.3282 - val_loss: 32.4642
# Epoch 21/30
# 43/43 [==============================] - 0s 398us/sample - loss: 28.2154 - val_loss: 33.2170
# Epoch 22/30
# 43/43 [==============================] - 0s 406us/sample - loss: 27.2236 - val_loss: 33.6118
# Epoch 23/30
# 43/43 [==============================] - 0s 414us/sample - loss: 26.3520 - val_loss: 33.7325
# Epoch 24/30
# 43/43 [==============================] - 0s 1ms/sample - loss: 25.2730 - val_loss: 33.4158
# Epoch 25/30
# 43/43 [==============================] - 0s 409us/sample - loss: 24.2127 - val_loss: 32.7676
# Epoch 26/30
# 43/43 [==============================] - 0s 385us/sample - loss: 23.1338 - val_loss: 32.1572
# Epoch 27/30
# 43/43 [==============================] - 0s 392us/sample - loss: 21.7907 - val_loss: 31.6848
# Epoch 28/30
# 43/43 [==============================] - 0s 401us/sample - loss: 20.2169 - val_loss: 31.1526
# Epoch 29/30
# 43/43 [==============================] - 0s 387us/sample - loss: 18.9178 - val_loss: 30.4159
# Epoch 30/30
# 43/43 [==============================] - 0s 403us/sample - loss: 17.3528 - val_loss: 29.5893
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 15:29:22.688627: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_27/BiasAdd' id:207 op device:{requested: '', assigned: ''} def:{{{node dense_27/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_27/MatMul, dense_27/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.695407: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.784743: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.790829: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_1/Assign' id:550 op device:{requested: '', assigned: ''} def:{{{node kernel_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_1, kernel_1/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.799674: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.824103: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.827722: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:603 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.836058: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.839047: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:599 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.846506: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.850848: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:605 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.857667: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.861860: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:517 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.868557: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.873038: W tensorflow/c/c_api.cc:304] Operation '{name:'mul/x' id:623 op device:{requested: '', assigned: ''} def:{{{node mul/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.881247: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.885199: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:620 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.891558: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.907874: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.911234: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1/x' id:655 op device:{requested: '', assigned: ''} def:{{{node mul_1/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.918305: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.921993: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:652 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.929874: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.948259: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.951373: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_conv2d_105/Conv2D/ReadVariableOp' id:670 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_105/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_105/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.958428: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.963053: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2/x' id:677 op device:{requested: '', assigned: ''} def:{{{node mul_2/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.970280: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.973709: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:674 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:22.980058: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.996445: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:22.999912: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_conv2d_104/Conv2D/ReadVariableOp' id:691 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_104/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_104/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:23.007044: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:23.010384: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_3/x' id:698 op device:{requested: '', assigned: ''} def:{{{node mul_3/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:23.017266: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:23.020890: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:695 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:23.027741: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:23.045007: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train on 43 samples, validate on 11 samples
# Epoch 1/30
# 2024-12-16 15:29:23.697168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:23.711709: W tensorflow/c/c_api.cc:304] Operation '{name:'training_2/Adam/conv2d_107/bias/m/Assign' id:964 op device:{requested: '', assigned: ''} def:{{{node training_2/Adam/conv2d_107/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_2/Adam/conv2d_107/bias/m, training_2/Adam/conv2d_107/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:23.725182: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:23.766756: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 8ms/sample - loss: 270.8602 - val_loss: 263.7934
# Epoch 2/30
# 43/43 [==============================] - 0s 462us/sample - loss: 203.3228 - val_loss: 158.6929
# Epoch 3/30
# 43/43 [==============================] - 0s 450us/sample - loss: 139.5658 - val_loss: 80.8623
# Epoch 4/30
# 43/43 [==============================] - 0s 548us/sample - loss: 104.8754 - val_loss: 72.3702
# Epoch 5/30
# 43/43 [==============================] - 0s 430us/sample - loss: 117.5472 - val_loss: 62.1872
# Epoch 6/30
# 43/43 [==============================] - 0s 441us/sample - loss: 103.7891 - val_loss: 47.7965
# Epoch 7/30
# 43/43 [==============================] - 0s 431us/sample - loss: 81.7627 - val_loss: 41.0160
# Epoch 8/30
# 43/43 [==============================] - 0s 414us/sample - loss: 74.6996 - val_loss: 35.2857
# Epoch 9/30
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 15:29:23.979193: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:828 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_29_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:23.993379: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 595us/sample - loss: 66.5511 - val_loss: 25.7481
# Epoch 10/30
# 43/43 [==============================] - 0s 455us/sample - loss: 57.7824 - val_loss: 19.5270
# Epoch 11/30
# 43/43 [==============================] - 0s 431us/sample - loss: 50.9655 - val_loss: 19.2029
# Epoch 12/30
# 43/43 [==============================] - 0s 555us/sample - loss: 42.8403 - val_loss: 23.6055
# Epoch 13/30
# 43/43 [==============================] - 0s 453us/sample - loss: 38.6877 - val_loss: 33.6222
# Epoch 14/30
# 43/43 [==============================] - 0s 451us/sample - loss: 34.6027 - val_loss: 42.5469
# Epoch 15/30
# 43/43 [==============================] - 0s 424us/sample - loss: 30.5487 - val_loss: 46.1987
# Epoch 16/30
# 43/43 [==============================] - 0s 1ms/sample - loss: 27.1690 - val_loss: 47.6960
# Epoch 17/30
# 43/43 [==============================] - 0s 434us/sample - loss: 25.8007 - val_loss: 50.8763
# Epoch 18/30
# 43/43 [==============================] - 0s 436us/sample - loss: 25.0438 - val_loss: 56.5165
# Epoch 19/30
# 43/43 [==============================] - 0s 451us/sample - loss: 24.4401 - val_loss: 59.2663
# Epoch 20/30
# 43/43 [==============================] - 0s 434us/sample - loss: 23.0642 - val_loss: 55.7332
# Epoch 21/30
# 43/43 [==============================] - 0s 429us/sample - loss: 21.6228 - val_loss: 50.9103
# Epoch 22/30
# 43/43 [==============================] - 0s 424us/sample - loss: 19.3914 - val_loss: 48.3010
# Epoch 23/30
# 43/43 [==============================] - 0s 392us/sample - loss: 16.6769 - val_loss: 45.5605
# Epoch 24/30
# 43/43 [==============================] - 0s 415us/sample - loss: 13.7139 - val_loss: 44.5325
# Epoch 25/30
# 43/43 [==============================] - 0s 405us/sample - loss: 11.5483 - val_loss: 45.9866
# Epoch 26/30
# 43/43 [==============================] - 0s 394us/sample - loss: 10.5540 - val_loss: 45.6497
# Epoch 27/30
# 43/43 [==============================] - 0s 391us/sample - loss: 10.0367 - val_loss: 42.4275
# Epoch 28/30
# 43/43 [==============================] - 0s 401us/sample - loss: 9.4879 - val_loss: 38.8185
# Epoch 29/30
# 43/43 [==============================] - 0s 369us/sample - loss: 8.6322 - val_loss: 34.6225
# Epoch 30/30
# 43/43 [==============================] - 0s 398us/sample - loss: 7.2999 - val_loss: 35.8834
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 15:29:24.626550: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_29/BiasAdd' id:810 op device:{requested: '', assigned: ''} def:{{{node dense_29/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_29/MatMul, dense_29/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.639806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.707508: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.714574: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_5/Assign' id:1143 op device:{requested: '', assigned: ''} def:{{{node kernel_5/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_5, kernel_5/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.726446: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.747987: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.753026: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/range' id:1196 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_6/MaxNeuronSelection_1/Max_grad/range/start, gradients_6/MaxNeuronSelection_1/Max_grad/Size, gradients_6/MaxNeuronSelection_1/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.764779: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.769047: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/mod' id:1192 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_6/MaxNeuronSelection_1/Max_grad/add, gradients_6/MaxNeuronSelection_1/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.781374: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.785156: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/ones' id:1198 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_6/MaxNeuronSelection_1/Max_grad/Shape_1, gradients_6/MaxNeuronSelection_1/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.798317: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.803483: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_1/Max/reduction_indices' id:1110 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_1/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.814941: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.820775: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:1216 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.833274: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.839191: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_4' id:1213 op device:{requested: '', assigned: ''} def:{{{node Const_4}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.850981: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.873932: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.878503: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:1248 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.890604: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.895169: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_5' id:1245 op device:{requested: '', assigned: ''} def:{{{node Const_5}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.908454: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.932114: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.936334: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_conv2d_107/Conv2D/ReadVariableOp' id:1263 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_107/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_107/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.947951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.953163: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:1270 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.965186: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:24.969714: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_6' id:1267 op device:{requested: '', assigned: ''} def:{{{node Const_6}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:24.981676: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.004657: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.009024: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_conv2d_106/Conv2D/ReadVariableOp' id:1284 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_106/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_106/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:25.022077: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.026769: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:1291 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:25.039127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.043818: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_7' id:1288 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:25.056259: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.084512: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train on 43 samples, validate on 11 samples
# Epoch 1/30
# 2024-12-16 15:29:25.315639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.331306: W tensorflow/c/c_api.cc:304] Operation '{name:'training_4/Adam/conv2d_109/kernel/v/Assign' id:1596 op device:{requested: '', assigned: ''} def:{{{node training_4/Adam/conv2d_109/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_4/Adam/conv2d_109/kernel/v, training_4/Adam/conv2d_109/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:25.349950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:25.393673: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 9ms/sample - loss: 279.4959 - val_loss: 266.6295
# Epoch 2/30
# 43/43 [==============================] - 0s 423us/sample - loss: 210.5407 - val_loss: 197.5978
# Epoch 3/30
# 43/43 [==============================] - 0s 436us/sample - loss: 146.9265 - val_loss: 143.3548
# Epoch 4/30
# 43/43 [==============================] - 0s 494us/sample - loss: 97.2554 - val_loss: 146.6370
# Epoch 5/30
# 43/43 [==============================] - 0s 444us/sample - loss: 111.3286 - val_loss: 146.7115
# Epoch 6/30
# 43/43 [==============================] - 0s 430us/sample - loss: 101.3102 - val_loss: 123.1078
# Epoch 7/30
# 43/43 [==============================] - 0s 428us/sample - loss: 74.2368 - val_loss: 114.6763
# Epoch 8/30
# 43/43 [==============================] - 0s 426us/sample - loss: 59.8773 - val_loss: 115.3274
# Epoch 9/30
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 15:29:25.600569: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_2/mul' id:1421 op device:{requested: '', assigned: ''} def:{{{node loss_2/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_2/mul/x, loss_2/dense_31_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:25.618236: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 43/43 [==============================] - 0s 1ms/sample - loss: 56.7330 - val_loss: 114.5698
# Epoch 10/30
# 43/43 [==============================] - 0s 480us/sample - loss: 52.7060 - val_loss: 110.2498
# Epoch 11/30
# 43/43 [==============================] - 0s 420us/sample - loss: 44.7934 - val_loss: 101.0013
# Epoch 12/30
# 43/43 [==============================] - 0s 412us/sample - loss: 35.8617 - val_loss: 88.8064
# Epoch 13/30
# 43/43 [==============================] - 0s 441us/sample - loss: 30.6524 - val_loss: 78.9447
# Epoch 14/30
# 43/43 [==============================] - 0s 427us/sample - loss: 27.8535 - val_loss: 73.0615
# Epoch 15/30
# 43/43 [==============================] - 0s 425us/sample - loss: 27.4476 - val_loss: 69.7461
# Epoch 16/30
# 43/43 [==============================] - 0s 443us/sample - loss: 26.0790 - val_loss: 68.9438
# Epoch 17/30
# 43/43 [==============================] - 0s 418us/sample - loss: 23.7738 - val_loss: 70.9207
# Epoch 18/30
# 43/43 [==============================] - 0s 410us/sample - loss: 21.9139 - val_loss: 73.5257
# Epoch 19/30
# 43/43 [==============================] - 0s 426us/sample - loss: 21.8000 - val_loss: 75.2513
# Epoch 20/30
# 43/43 [==============================] - 0s 401us/sample - loss: 21.9380 - val_loss: 74.4478
# Epoch 21/30
# 43/43 [==============================] - 0s 492us/sample - loss: 21.3620 - val_loss: 69.1793
# Epoch 22/30
# 43/43 [==============================] - 0s 425us/sample - loss: 18.7294 - val_loss: 60.5962
# Epoch 23/30
# 43/43 [==============================] - 0s 425us/sample - loss: 15.8194 - val_loss: 52.4512
# Epoch 24/30
# 43/43 [==============================] - 0s 443us/sample - loss: 15.3300 - val_loss: 47.2669
# Epoch 25/30
# 43/43 [==============================] - 0s 435us/sample - loss: 15.7280 - val_loss: 45.5373
# Epoch 26/30
# 43/43 [==============================] - 0s 412us/sample - loss: 14.4599 - val_loss: 45.8084
# Epoch 27/30
# 43/43 [==============================] - 0s 410us/sample - loss: 12.2174 - val_loss: 46.6600
# Epoch 28/30
# 43/43 [==============================] - 0s 429us/sample - loss: 11.4511 - val_loss: 47.9111
# Epoch 29/30
# 43/43 [==============================] - 0s 407us/sample - loss: 11.1193 - val_loss: 46.7798
# Epoch 30/30
# 43/43 [==============================] - 0s 419us/sample - loss: 10.5000 - val_loss: 42.9710
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 15:29:26.245811: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_31/BiasAdd' id:1403 op device:{requested: '', assigned: ''} def:{{{node dense_31/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_31/MatMul, dense_31/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.267658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.345919: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.354838: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_10/Assign' id:1755 op device:{requested: '', assigned: ''} def:{{{node kernel_10/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_10, kernel_10/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.372434: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.399151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.405020: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/range' id:1789 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_12/MaxNeuronSelection_2/Max_grad/range/start, gradients_12/MaxNeuronSelection_2/Max_grad/Size, gradients_12/MaxNeuronSelection_2/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.426263: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.432088: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/mod' id:1785 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_12/MaxNeuronSelection_2/Max_grad/add, gradients_12/MaxNeuronSelection_2/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.452685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.458404: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/ones' id:1791 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_12/MaxNeuronSelection_2/Max_grad/Shape_1, gradients_12/MaxNeuronSelection_2/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.476500: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.483366: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_2/Max/reduction_indices' id:1703 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_2/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.501763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.508935: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_8/x' id:1809 op device:{requested: '', assigned: ''} def:{{{node mul_8/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.527342: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.533501: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_8' id:1806 op device:{requested: '', assigned: ''} def:{{{node Const_8}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:26.554193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:26.584461: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...
# 44/44 [==============================] - 0s 363us/sample - loss: 11.6408 - val_loss: 16.0800
# Epoch 27/30
# 44/44 [==============================] - 0s 445us/sample - loss: 10.2458 - val_loss: 17.2287
# Epoch 28/30
# 44/44 [==============================] - 0s 376us/sample - loss: 8.9956 - val_loss: 17.7926
# Epoch 29/30
# 44/44 [==============================] - 0s 373us/sample - loss: 8.0509 - val_loss: 18.4630
# Epoch 30/30
# 44/44 [==============================] - 0s 364us/sample - loss: 7.8526 - val_loss: 19.3694
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 15:29:30.124381: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_35/BiasAdd' id:2589 op device:{requested: '', assigned: ''} def:{{{node dense_35/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_35/MatMul, dense_35/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.153838: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.236904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.246923: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_19/Assign' id:2960 op device:{requested: '', assigned: ''} def:{{{node kernel_19/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_19, kernel_19/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.274574: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.301969: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.309510: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_24/MaxNeuronSelection_4/Max_grad/range' id:2975 op device:{requested: '', assigned: ''} def:{{{node gradients_24/MaxNeuronSelection_4/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_4/Max"], _has_manual_control_dependencies=true](gradients_24/MaxNeuronSelection_4/Max_grad/range/start, gradients_24/MaxNeuronSelection_4/Max_grad/Size, gradients_24/MaxNeuronSelection_4/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.339787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.347124: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_24/MaxNeuronSelection_4/Max_grad/mod' id:2971 op device:{requested: '', assigned: ''} def:{{{node gradients_24/MaxNeuronSelection_4/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_4/Max"], _has_manual_control_dependencies=true](gradients_24/MaxNeuronSelection_4/Max_grad/add, gradients_24/MaxNeuronSelection_4/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.376904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.384349: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_24/MaxNeuronSelection_4/Max_grad/ones' id:2977 op device:{requested: '', assigned: ''} def:{{{node gradients_24/MaxNeuronSelection_4/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_4/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_24/MaxNeuronSelection_4/Max_grad/Shape_1, gradients_24/MaxNeuronSelection_4/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.413852: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.422458: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_4/Max/reduction_indices' id:2889 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_4/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.451162: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.459727: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_16/x' id:2995 op device:{requested: '', assigned: ''} def:{{{node mul_16/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.487074: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.494544: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_16' id:2992 op device:{requested: '', assigned: ''} def:{{{node Const_16}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.522991: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.564164: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.572018: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_17/x' id:3027 op device:{requested: '', assigned: ''} def:{{{node mul_17/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.600580: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.608127: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_17' id:3024 op device:{requested: '', assigned: ''} def:{{{node Const_17}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.636341: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.680087: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.687693: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_conv2d_113/Conv2D/ReadVariableOp' id:3042 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_113/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_113/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.716589: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.724853: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_18/x' id:3049 op device:{requested: '', assigned: ''} def:{{{node mul_18/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.754483: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.762893: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_18' id:3046 op device:{requested: '', assigned: ''} def:{{{node Const_18}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.793364: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.838090: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.846441: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_conv2d_112/Conv2D/ReadVariableOp' id:3063 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_112/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_112/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.875571: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.883415: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_19/x' id:3070 op device:{requested: '', assigned: ''} def:{{{node mul_19/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.913957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.922543: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_19' id:3067 op device:{requested: '', assigned: ''} def:{{{node Const_19}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 15:29:30.953110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 15:29:30.997242: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# R2 Score: 0.6567
# MSE: 35.4466
#
# Top 10 Features by Relevance:
#                                                       Fold_0    Fold_1  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.218976  0.309958
# d__Bacteria;p__Bdellovibrionota;c__Oligoflexia;...  0.184825  0.290532
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.228910  0.189231
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.127278  0.236007
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.157463  0.198628
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.141624  0.178766
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...  0.179691  0.182948
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.146925  0.136751
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.139216  0.115580
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.185119  0.189965
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.132544  0.326074
# d__Bacteria;p__Bdellovibrionota;c__Oligoflexia;...  0.260154  0.252036
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.204741  0.217936
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.068033  0.215844
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.178959  0.201933
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.109958  0.179120
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...  0.168265  0.167368
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.175589  0.200706
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.195857  0.218686
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.120667  0.129392
#
#                                                       Fold_4  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.357784
# d__Bacteria;p__Bdellovibrionota;c__Oligoflexia;...  0.179595
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.134769
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.243373
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.146806
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.242389
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...  0.128278
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.159193
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.137263
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.161621
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...            0.269067
# d__Bacteria;p__Bdellovibrionota;c__Oligoflexia;...            0.233428
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...            0.195117
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...            0.178107
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...            0.176758
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...            0.170371
# d__Archaea;p__Euryarchaeota;c__Thermococci;o__M...            0.165310
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...            0.163833
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...            0.161321
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.157353

# %% [markdown]
# ## LRP and Feature Selection

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from scipy.cluster.hierarchy import linkage, leaves_list
import innvestigate


# -------------------------------------------------------------
# DEFINE CNN MODEL FUNCTION
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = Sequential([
        Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        Conv2D(32, kernel_size=(3, 3), activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

### Run Neural Network Cross Validation
lrp_cache = pd.DataFrame()
ann_predictions = np.array([])
ann_actuals = np.array([])  # To store actual values for plotting
history_cache = []

# Convert boolean columns to integers (if not already done)
X = X.astype({col: 'int32' for col in X.select_dtypes('bool').columns})

# Specify the target column for single-output regression
target_column = 'ACE-km'  # Replace with your target column name

# -------------------------------------------------------------
# FEATURE SELECTION AND HIERARCHICAL CLUSTERING
# -------------------------------------------------------------
# Select top `num_features` based on variance
num_features = 400  # Change as needed
if X.shape[1] > num_features:
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

# Hierarchical clustering to reorder features
corr = X.corr().fillna(0)  # Compute correlation matrix
Z = linkage(1 - corr, method='average')  # Perform hierarchical clustering
leaf_order = leaves_list(Z)  # Get feature order based on clustering
X = X.iloc[:, leaf_order]  # Reorder features based on clustering

# -------------------------------------------------------------
# PREPROCESSING
# -------------------------------------------------------------
# Pad features to form a square grid for potential 2D inputs
num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))  # Determine grid size
padding = grid_size**2 - num_features_final  # Calculate necessary padding

# Add padding columns with zeros if required
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.values)  # Convert to numpy array after scaling

# -------------------------------------------------------------
# CROSS-VALIDATION WITH LRP
# -------------------------------------------------------------
for fold in range(num_folds):

    # Reset keras session to reduce model clutter
    tf.keras.backend.clear_session()

    # Define train-test splits
    X_val = X_scaled[chunks[fold]:chunks[fold + 1]]
    y_val = y[chunks[fold]:chunks[fold + 1]][target_column]

    X_train = np.delete(X_scaled, np.arange(chunks[fold], chunks[fold + 1]), axis=0)
    y_train = y.drop(y_val.index)[target_column]

    # Ensure target values are numeric and have the correct shape
    y_train = y_train.astype(float).values
    y_val = y_val.astype(float).values

    # Reshape data for neural network input
    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)  # Add channel dimension
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)  # Add channel dimension

    # Build and train the neural network model
    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, batch_size=32, epochs=150, verbose=0, validation_data=(X_val, y_val))

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)
    relevance_scores = analyzer.analyze(X_train)  # Analyze training data

    # Flatten relevance scores and trim to original feature dimensions
    relevance_scores_flat = relevance_scores.mean(axis=0).flatten()[:num_features_final]

    # Store LRP results for original features only
    lrp = pd.DataFrame(relevance_scores_flat, index=X.columns[:num_features_final], columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, lrp], axis=1)

    # Predict and store validation results
    predictions = model.predict(X_val).flatten()
    ann_predictions = np.concatenate([ann_predictions, predictions])
    ann_actuals = np.concatenate([ann_actuals, y_val])  # Store actual values for plotting
    history_cache.append(model.history)

# -------------------------------------------------------------
# EVALUATE MODEL PERFORMANCE
# -------------------------------------------------------------
ann_r2 = r2_score(ann_actuals, ann_predictions)  # R² for regression
ann_mse = mean_squared_error(ann_actuals, ann_predictions)  # MSE for regression

print("\nCross Validation Results:\n")
print("Neural Network R2 Score: {:.5f}".format(ann_r2))
print("Mean Squared Error: {:.5f}".format(ann_mse))

# -------------------------------------------------------------
# SAVE LRP RESULTS
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

lrp_cache.to_csv("lrp_feature_relevance.csv")

# -------------------------------------------------------------
# PLOT PREDICTED VS ACTUAL VALUES
# -------------------------------------------------------------
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.scatter(ann_actuals, ann_predictions, alpha=0.6, edgecolor='k', label="Predictions")
plt.plot([ann_actuals.min(), ann_actuals.max()],
         [ann_actuals.min(), ann_actuals.max()],
         color='red', linestyle='--', label='Ideal Fit')
plt.title("Predicted vs Actual Values (All Folds)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.grid(True)
plt.savefig("predicted_vs_actual_plot.png")
plt.show()
# Out:
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_60134/860659427.py:36: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')  # Perform hierarchical clustering
# 2024-12-16 16:10:42.452231: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 16:10:42.452250: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 16:10:42.459385: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:42.472015: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_1/kernel/v/Assign' id:316 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_1/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_1/kernel/v, training/Adam/dense_1/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:42.475963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:42.503942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 16:10:42.969850: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:42.974002: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.035213: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.039373: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_2/Assign' id:460 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.044573: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.058045: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.073186: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.078725: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.081312: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.086385: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.089444: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.094437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.098538: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.103640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.107963: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.113169: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.116664: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.121652: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.130230: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.135213: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.151515: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.156703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.160048: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.165141: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.175344: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.180744: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.196237: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.201330: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.217658: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.223070: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.226458: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.231696: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.241116: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.246595: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.263228: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.268699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.285171: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.290791: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.294215: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.299656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:45.312887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:45.548510: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.554135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.673552: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 16:10:45.673570: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 16:10:45.680643: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.693305: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/conv2d_1/bias/v/Assign' id:299 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d_1/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d_1/bias/v, training/Adam/conv2d_1/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.697095: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:45.726066: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 16:10:45.900030: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:45.904202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.009437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.013402: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_2/Assign' id:460 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.018340: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.030994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.051064: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.056375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.059101: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.064094: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.066636: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.071510: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.075366: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.080310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.084169: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.089054: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.092175: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.097409: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.105405: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.110966: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.126220: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.131458: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.134862: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.140334: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.150045: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.155341: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.170473: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.175670: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.191961: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.197469: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.200943: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.206319: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.215884: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.221245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.238606: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.244251: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.260695: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.266192: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.269649: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.274934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:48.287731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:48.414749: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.420554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.541840: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 16:10:48.541858: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 16:10:48.549200: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.561573: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/conv2d/bias/m/Assign' id:243 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d/bias/m, training/Adam/conv2d/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.565773: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:48.592823: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 16:10:48.762398: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:119 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:48.766686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.858612: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.863003: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_3/Assign' id:480 op device:{requested: '', assigned: ''} def:{{{node kernel_3/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_3, kernel_3/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.868004: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.881903: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.897711: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.902636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.905434: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.910802: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.913285: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.918310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.922489: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.927504: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.931327: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.936670: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.939971: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.944983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.952577: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.957984: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.973735: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.978963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.982312: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:50.987564: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:50.997417: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.002575: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.018491: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.023680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.039261: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.044742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.048173: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.053566: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.062994: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.068703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.084984: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.090519: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.105880: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.111357: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:51.114886: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:51.120377: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:51.133667: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# ...
# 2024-12-16 16:10:57.101515: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.106606: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.109342: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.114585: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.117145: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.122308: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.126491: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.131496: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.135195: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.140340: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.143800: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.148884: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.157005: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.162383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.178190: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.183297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.186784: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.191809: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.201572: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.207069: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.222399: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.228195: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.245095: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.250437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.253630: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.258772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.267922: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.273274: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.288900: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.294319: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.310112: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.315401: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 16:10:57.318680: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.324405: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:57.337930: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Cross Validation Results:
#
# Neural Network R2 Score: 0.40685
# Mean Squared Error: 61.24905
#
# Top 10 Features by Relevance:
#                                                       Fold_0    Fold_1  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.366577  0.276790
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.261308  0.354189
# d__Bacteria;p__Planctomycetota;c__Pla4_lineage;...  0.231701  0.320676
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.173428  0.203659
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.180622  0.183965
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.209367  0.197617
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.095076  0.120176
# d__Bacteria;p__MBNT15;c__MBNT15;o__MBNT15;f__MB...  0.148831  0.164191
# d__Bacteria;p__Synergistota;c__Synergistia;o__S...  0.166302  0.167118
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  0.166009  0.224010
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.104420  0.345324
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.044007  0.318889
# d__Bacteria;p__Planctomycetota;c__Pla4_lineage;...  0.112550  0.334772
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.175334 -0.306056
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.112141  0.301970
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.038649  0.261819
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.126865 -0.443081
# d__Bacteria;p__MBNT15;c__MBNT15;o__MBNT15;f__MB...  0.084438  0.298053
# d__Bacteria;p__Synergistota;c__Synergistia;o__S...  0.175302  0.230095
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  0.024869  0.234936
#
#                                                       Fold_4  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.177112
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...  0.280592
# d__Bacteria;p__Planctomycetota;c__Pla4_lineage;...  0.209555
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.160052
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.185268
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.199233
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.099262
# d__Bacteria;p__MBNT15;c__MBNT15;o__MBNT15;f__MB...  0.158176
# d__Bacteria;p__Synergistota;c__Synergistia;o__S...  0.114763
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  0.199497
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...            0.254045
# d__Bacteria;p__Planctomycetota;c__Phycisphaerae...            0.251797
# d__Bacteria;p__Planctomycetota;c__Pla4_lineage;...            0.241851
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...            0.203706
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.192793
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...            0.181337
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...            0.176892
# d__Bacteria;p__MBNT15;c__MBNT15;o__MBNT15;f__MB...            0.170738
# d__Bacteria;p__Synergistota;c__Synergistia;o__S...            0.170716
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.169864
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 16:10:57.473277: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:101 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 16:10:57.479125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Feature Processing + LRP + LOGO

# %%
# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns].apply(pd.to_numeric, errors='coerce')
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import LeaveOneGroupOut
import innvestigate
from scipy.cluster.hierarchy import linkage, leaves_list

# -------------------------------------------------------------
# LOADING AND PREPARING DATA
# -------------------------------------------------------------
def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns] # .apply(pd.to_numeric, errors='coerce')

# -------------------------------------------------------------
# DEFINE CNN MODEL FUNCTION
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])
    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss='mse')
    return model

### Initialize LOGO
logo = LeaveOneGroupOut()

### Run Neural Network Cross Validation
lrp_cache = pd.DataFrame()
ann_predictions = np.array([])
ann_actuals = np.array([])  # To store actual values for plotting
history_cache = []

# Convert boolean columns to integers (if not already done)
X = X.astype({col: 'int32' for col in X.select_dtypes('bool').columns})

# Specify the target column for single-output regression
target_column = 'H2-km'  # Replace with your target column name
groups = y['Digester']  # Use Digester as the grouping variable

# -------------------------------------------------------------
# FEATURE SELECTION AND HIERARCHICAL CLUSTERING
# -------------------------------------------------------------
# Select top `num_features` based on variance
num_features = 200  # Change as needed
if X.shape[1] > num_features:
    feature_variances = X.var().sort_values(ascending=False)
    top_features = feature_variances.index[:num_features]
    X = X[top_features]

# Hierarchical clustering to reorder features
corr = X.corr().fillna(0)  # Compute correlation matrix
Z = linkage(1 - corr, method='average')  # Perform hierarchical clustering
leaf_order = leaves_list(Z)  # Get feature order based on clustering
X = X.iloc[:, leaf_order]  # Reorder features based on clustering

# -------------------------------------------------------------
# PREPROCESSING
# -------------------------------------------------------------
# Pad features to form a square grid for potential 2D inputs
num_features_final = X.shape[1]
grid_size = int(np.ceil(np.sqrt(num_features_final)))  # Determine grid size
padding = grid_size**2 - num_features_final  # Calculate necessary padding

# Add padding columns with zeros if required
if padding > 0:
    extra_cols = pd.DataFrame(0, index=X.index, columns=[f"pad_{i}" for i in range(padding)])
    X = pd.concat([X, extra_cols], axis=1)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.values)  # Convert to numpy array after scaling

# -------------------------------------------------------------
# LOGO CROSS-VALIDATION WITH LRP
# -------------------------------------------------------------
for fold, (train_idx, val_idx) in enumerate(logo.split(X_scaled, y[target_column], groups=groups)):
    print(f"Processing Fold {fold + 1}")

    # Define train-test splits
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y.iloc[train_idx][target_column], y.iloc[val_idx][target_column]

    # Ensure target values are numeric and have the correct shape
    y_train = y_train.astype(float).values
    y_val = y_val.astype(float).values

    # Reshape data for neural network input
    X_train = X_train.reshape(X_train.shape[0], grid_size, grid_size, 1)  # Add channel dimension
    X_val = X_val.reshape(X_val.shape[0], grid_size, grid_size, 1)  # Add channel dimension

    # Build and train the neural network model
    model = build_cnn_model((grid_size, grid_size, 1))
    model.fit(X_train, y_train, batch_size=32, epochs=150, verbose=0, validation_data=(X_val, y_val))

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)
    relevance_scores = analyzer.analyze(X_train)  # Analyze training data

    # Flatten relevance scores and trim to original feature dimensions
    relevance_scores_flat = relevance_scores.mean(axis=0).flatten()[:num_features_final]

    # Store LRP results for original features only
    lrp = pd.DataFrame(relevance_scores_flat, index=X.columns[:num_features_final], columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, lrp], axis=1)

    # Predict and store validation results
    predictions = model.predict(X_val).flatten()
    ann_predictions = np.concatenate([ann_predictions, predictions])
    ann_actuals = np.concatenate([ann_actuals, y_val])  # Store actual values for plotting
    history_cache.append(model.history)

# -------------------------------------------------------------
# EVALUATE MODEL PERFORMANCE
# -------------------------------------------------------------
ann_r2 = r2_score(ann_actuals, ann_predictions)  # R² for regression
ann_mse = mean_squared_error(ann_actuals, ann_predictions)  # MSE for regression

print("\nCross Validation Results:\n")
print("Neural Network R2 Score: {:.5f}".format(ann_r2))
print("Mean Squared Error: {:.5f}".format(ann_mse))

# -------------------------------------------------------------
# SAVE LRP RESULTS
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

lrp_cache.to_csv("lrp_feature_relevance.csv")

# -------------------------------------------------------------
# PLOT PREDICTED VS ACTUAL VALUES
# -------------------------------------------------------------
plt.figure(figsize=(10, 8))
plt.scatter(ann_actuals, ann_predictions, alpha=0.6, edgecolor='k', label="Predictions")
plt.plot([ann_actuals.min(), ann_actuals.max()],
         [ann_actuals.min(), ann_actuals.max()],
         color='red', linestyle='--', label='Ideal Fit')
plt.title("Predicted vs Actual Values (LOGO CV)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.grid(True)
plt.savefig("predicted_vs_actual_plot_logo.png")
plt.show()


# -------------------------------------------------------------
# GENERATE TABLE WITH TOP 10 SELECTED FEATURES
# -------------------------------------------------------------
# Calculate the mean absolute relevance for each feature across all folds
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)

# Sort features by mean absolute relevance
lrp_cache_sorted = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

# Extract the top 10 features
top_10_features = lrp_cache_sorted.head(10)

# Print the table
print("\nTop 10 Features Based on Mean Absolute Relevance Across All Folds:")
print(top_10_features)

# Save the table as a CSV file
top_10_features.to_csv("top_10_features.csv")

# Display the table in a formatted output
from IPython.display import display
display(top_10_features)
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Processing Fold 1
# /var/folders/0k/33xc23rd39v28fxtr5xb2gbh0000gn/T/ipykernel_2116/3613053180.py:78: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(1 - corr, method='average')  # Perform hierarchical clustering
# 2024-12-16 19:46:33.801375: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-12-16 19:46:33.801446: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-16 19:46:33.801457: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-16 19:46:33.801495: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 19:46:33.801513: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 19:46:33.807900: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2024-12-16 19:46:33.810374: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:33.825514: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_1/kernel/m/Assign' id:272 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_1/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_1/kernel/m, training/Adam/dense_1/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:33.829718: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:33.858559: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 19:46:34.155668: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:117 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:34.159816: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.064926: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.068880: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel/Assign' id:420 op device:{requested: '', assigned: ''} def:{{{node kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel, kernel/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.073821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.084789: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.102887: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:490 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.107750: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.110397: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:486 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.115619: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.118841: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:492 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.123758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.127833: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:400 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.132964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.137080: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4/x' id:507 op device:{requested: '', assigned: ''} def:{{{node mul_4/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.141943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.145060: W tensorflow/c/c_api.cc:304] Operation '{name:'Const' id:504 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.149814: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.157664: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_2' id:447 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_5, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.162778: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.181998: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5/x' id:531 op device:{requested: '', assigned: ''} def:{{{node mul_5/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.187425: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.190850: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_1' id:528 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.196067: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.206001: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.211395: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.228943: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:427 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_3, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.234320: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.249903: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_6/x' id:549 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.255317: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.258449: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:546 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.263757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.272082: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.277413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.296000: W tensorflow/c/c_api.cc:304] Operation '{name:'mul' id:407 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_1, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.301545: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.316434: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:566 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.321788: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.325197: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:563 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.330722: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 19:46:36.344228: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 19:46:36.507495: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:99 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.513035: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.646620: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.660150: W tensorflow/c/c_api.cc:304] Operation '{name:'training_2/Adam/dense_3/bias/v/Assign' id:898 op device:{requested: '', assigned: ''} def:{{{node training_2/Adam/dense_3/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_2/Adam/dense_3/bias/v, training_2/Adam/dense_3/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.669190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:36.696752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Processing Fold 2
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 19:46:36.869222: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:696 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:36.878890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.741232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.746091: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_7/Assign' id:1057 op device:{requested: '', assigned: ''} def:{{{node kernel_7/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_7, kernel_7/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.756125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.768755: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.785941: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/range' id:1067 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_6/MaxNeuronSelection_1/Max_grad/range/start, gradients_6/MaxNeuronSelection_1/Max_grad/Size, gradients_6/MaxNeuronSelection_1/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.795728: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.799475: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/mod' id:1063 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_6/MaxNeuronSelection_1/Max_grad/add, gradients_6/MaxNeuronSelection_1/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.809803: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.813342: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_6/MaxNeuronSelection_1/Max_grad/ones' id:1069 op device:{requested: '', assigned: ''} def:{{{node gradients_6/MaxNeuronSelection_1/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_6/MaxNeuronSelection_1/Max_grad/Shape_1, gradients_6/MaxNeuronSelection_1/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.823324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.828490: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_1/Max/reduction_indices' id:977 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_1/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.838638: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.843520: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_12/x' id:1084 op device:{requested: '', assigned: ''} def:{{{node mul_12/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.853551: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.857575: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_4' id:1081 op device:{requested: '', assigned: ''} def:{{{node Const_4}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.868103: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.876784: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_10' id:1024 op device:{requested: '', assigned: ''} def:{{{node mul_10}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_10)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.886851: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.903666: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_13/x' id:1108 op device:{requested: '', assigned: ''} def:{{{node mul_13/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.914050: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.918444: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_5' id:1105 op device:{requested: '', assigned: ''} def:{{{node Const_5}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.928848: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.939738: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_9' id:1004 op device:{requested: '', assigned: ''} def:{{{node mul_9}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast_9)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.950329: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.968421: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_9' id:1004 op device:{requested: '', assigned: ''} def:{{{node mul_9}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast_9)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:38.978674: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:38.996914: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_14/x' id:1126 op device:{requested: '', assigned: ''} def:{{{node mul_14/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.007514: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.011863: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_6' id:1123 op device:{requested: '', assigned: ''} def:{{{node Const_6}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.022476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.032033: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_8' id:984 op device:{requested: '', assigned: ''} def:{{{node mul_8}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_9, Cast_8)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.042715: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.060012: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_8' id:984 op device:{requested: '', assigned: ''} def:{{{node mul_8}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_9, Cast_8)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.070551: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.086700: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_15/x' id:1143 op device:{requested: '', assigned: ''} def:{{{node mul_15/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.097238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.101587: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_7' id:1140 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.111982: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 19:46:39.131065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 19:46:39.262107: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:678 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.272963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.376910: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.390719: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_4/bias/Assign' id:1226 op device:{requested: '', assigned: ''} def:{{{node dense_4/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_4/bias, dense_4/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.404543: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:39.433850: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Processing Fold 3
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 19:46:39.623724: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_2/mul' id:1273 op device:{requested: '', assigned: ''} def:{{{node loss_2/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_2/mul/x, loss_2/dense_5_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:39.639125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.564222: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.570088: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_9/Assign' id:1594 op device:{requested: '', assigned: ''} def:{{{node kernel_9/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_9, kernel_9/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.585524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.599941: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.616424: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/range' id:1644 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_12/MaxNeuronSelection_2/Max_grad/range/start, gradients_12/MaxNeuronSelection_2/Max_grad/Size, gradients_12/MaxNeuronSelection_2/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.631980: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.636765: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/mod' id:1640 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_12/MaxNeuronSelection_2/Max_grad/add, gradients_12/MaxNeuronSelection_2/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.651876: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.656287: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_12/MaxNeuronSelection_2/Max_grad/ones' id:1646 op device:{requested: '', assigned: ''} def:{{{node gradients_12/MaxNeuronSelection_2/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_12/MaxNeuronSelection_2/Max_grad/Shape_1, gradients_12/MaxNeuronSelection_2/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.671248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.676951: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_2/Max/reduction_indices' id:1554 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_2/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.692025: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.697951: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_20/x' id:1661 op device:{requested: '', assigned: ''} def:{{{node mul_20/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.713489: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.718644: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_8' id:1658 op device:{requested: '', assigned: ''} def:{{{node Const_8}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.733931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.743870: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_18' id:1601 op device:{requested: '', assigned: ''} def:{{{node mul_18}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_21, Cast_18)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.758945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.777953: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_21/x' id:1685 op device:{requested: '', assigned: ''} def:{{{node mul_21/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.793190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.798547: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_9' id:1682 op device:{requested: '', assigned: ''} def:{{{node Const_9}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.814315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.825693: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_17' id:1581 op device:{requested: '', assigned: ''} def:{{{node mul_17}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_19, Cast_17)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.841016: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.859153: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_17' id:1581 op device:{requested: '', assigned: ''} def:{{{node mul_17}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_19, Cast_17)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.874618: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.892493: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_22/x' id:1703 op device:{requested: '', assigned: ''} def:{{{node mul_22/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.907911: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.912914: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_10' id:1700 op device:{requested: '', assigned: ''} def:{{{node Const_10}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.928088: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.938919: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_16' id:1561 op device:{requested: '', assigned: ''} def:{{{node mul_16}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_17, Cast_16)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.954072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:41.972379: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_16' id:1561 op device:{requested: '', assigned: ''} def:{{{node mul_16}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_17, Cast_16)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:41.987684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:42.006104: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_23/x' id:1720 op device:{requested: '', assigned: ''} def:{{{node mul_23/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:42.021632: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 19:46:42.026845: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_11' id:1717 op device:{requested: '', assigned: ''} def:{{{node Const_11}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 19:46:42.042815: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 19:46:42.068099: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# ...
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  1.007981  0.849540
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.994421  0.854609
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.792234  0.642090
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.773683  0.717624
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.764324  0.568826
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.873223  0.713939
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.783095  0.516274
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.254872  1.479780
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.243518  0.985410
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.075662  1.078528
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.942687  0.934657
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.799151  0.794789
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.716941  1.051002
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.721481  0.593476
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.754614  0.709681
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.674357  0.797617
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.693385  0.827591
#
#                                                       Fold_4    Fold_5  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.371503  1.437509
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.332561  0.882941
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.132908  1.092860
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.836094  1.003040
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.839801  1.191159
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.826560  0.205881
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.632202  0.940280
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.732856  1.000666
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.831050  1.013480
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.700320  0.812371
#
#                                                       Fold_6    Fold_7  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.362065  1.441241
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.803394  1.214500
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.747056  1.161088
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.902560  0.957762
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.587325  0.736775
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.822625  0.624077
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.874549  0.777023
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.798069  0.657342
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.444724  0.596344
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.684028  0.726524
#
#                                                       Fold_8    Fold_9  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.590954  1.152032
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.410754  1.024850
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.241272  0.957092
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  1.128799  0.792946
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.879845  0.934216
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.739724  0.854243
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.928287  0.716816
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.794336  0.703348
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.773930  0.760567
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.557161  0.702028
#
#                                                      Fold_10   Fold_11  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.209959  1.430500
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.237260  1.073619
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.083467  1.054706
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.871089  0.880855
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  1.052879  0.812541
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.674398  0.766956
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.759540  0.812967
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.821778  0.786428
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.843049  0.684442
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.857325  0.633959
#
#                                                      Fold_12   Fold_13  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.361000  1.645676
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.170681  1.210894
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.993976  1.169106
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.858971  1.081175
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.908936  0.853714
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.840932  0.934889
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.777953  0.925468
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.638631  0.933976
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.707201  0.764857
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.686233  0.701763
#
#                                                      Fold_14   Fold_15  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.684387  0.952027
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.189901  0.929688
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.214501  0.808932
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.977510  0.715021
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  1.157695  0.571090
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.842499  0.791292
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.932688  0.544567
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.871767  0.613555
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.947738  0.551881
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.830436  0.671864
#
#                                                      Fold_16   Fold_17  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.197814  0.701397
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.051152  0.651712
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.967132  0.712417
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.849273  0.580879
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.847735  0.304525
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.855098  0.774828
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.717665  0.323503
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.694662  0.486830
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.663156  0.144855
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.713271  0.316357
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            1.341946
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...            1.085663
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...            1.030227
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.898380
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...            0.840067
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...            0.764237
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...            0.748321
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.740649
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...            0.710356
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...            0.689666
#                                                       Fold_0    Fold_1  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.554159  1.328153
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.092423  1.036684
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.062176  0.991212
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  1.007981  0.849540
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.994421  0.854609
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.792234  0.642090
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.773683  0.717624
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.764324  0.568826
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.873223  0.713939
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.783095  0.516274
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.254872  1.479780
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.243518  0.985410
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.075662  1.078528
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.942687  0.934657
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.799151  0.794789
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.716941  1.051002
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.721481  0.593476
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.754614  0.709681
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.674357  0.797617
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.693385  0.827591
#
#                                                       Fold_4    Fold_5  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.371503  1.437509
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.332561  0.882941
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.132908  1.092860
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.836094  1.003040
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.839801  1.191159
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.826560  0.205881
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.632202  0.940280
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.732856  1.000666
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.831050  1.013480
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.700320  0.812371
#
#                                                       Fold_6    Fold_7  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.362065  1.441241
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.803394  1.214500
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.747056  1.161088
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.902560  0.957762
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.587325  0.736775
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.822625  0.624077
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.874549  0.777023
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.798069  0.657342
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.444724  0.596344
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.684028  0.726524
#
#                                                       Fold_8    Fold_9  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.590954  1.152032
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.410754  1.024850
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.241272  0.957092
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  1.128799  0.792946
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.879845  0.934216
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.739724  0.854243
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.928287  0.716816
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.794336  0.703348
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.773930  0.760567
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.557161  0.702028
#
#                                                      Fold_10   Fold_11  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.209959  1.430500
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.237260  1.073619
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.083467  1.054706
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.871089  0.880855
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  1.052879  0.812541
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.674398  0.766956
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.759540  0.812967
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.821778  0.786428
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.843049  0.684442
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.857325  0.633959
#
#                                                      Fold_12   Fold_13  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.361000  1.645676
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.170681  1.210894
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.993976  1.169106
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.858971  1.081175
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.908936  0.853714
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.840932  0.934889
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.777953  0.925468
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.638631  0.933976
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.707201  0.764857
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.686233  0.701763
#
#                                                      Fold_14   Fold_15  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.684387  0.952027
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.189901  0.929688
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.214501  0.808932
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.977510  0.715021
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  1.157695  0.571090
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.842499  0.791292
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.932688  0.544567
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.871767  0.613555
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.947738  0.551881
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.830436  0.671864
#
#                                                      Fold_16   Fold_17  \
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.197814  0.701397
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  1.051152  0.651712
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...  0.967132  0.712417
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  0.849273  0.580879
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...  0.847735  0.304525
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...  0.855098  0.774828
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...  0.717665  0.323503
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.694662  0.486830
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...  0.663156  0.144855
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.713271  0.316357
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            1.341946
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...            1.085663
# d__Bacteria;p__Chloroflexi;c__Anaerolineae;o__A...            1.030227
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...            0.898380
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Izemopl...            0.840067
# d__Bacteria;p__Desulfobacterota;c__Syntrophorha...            0.764237
# d__Bacteria;p__Cloacimonadota;c__Cloacimonadia;...            0.748321
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.740649
# d__Bacteria;p__Verrucomicrobiota;c__Kiritimatie...            0.710356
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...            0.689666

# %% [markdown]
# ## Only LRP

# %%
import tensorflow as tf
# Do not disable eager execution unless absolutely necessary
# tf.compat.v1.disable_eager_execution()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
import innvestigate
from tensorflow.keras.layers import Conv1D, Flatten, Dense

# -------------------------------------------------------------
# DEFINE CNN MODEL FUNCTION
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(16, kernel_size=3, activation='relu', input_shape=input_shape),
        tf.keras.layers.Conv1D(32, kernel_size=3, activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])
    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss='mse')
    return model

### Run Neural Network Cross Validation
lrp_cache = pd.DataFrame()
ann_predictions = np.array([])
ann_actuals = np.array([])  # To store actual values for plotting
history_cache = []

# Specify the target column for single-output regression
target_column = 'ACE-km'  # Replace with your target column name

# -------------------------------------------------------------
# PREPROCESSING
# -------------------------------------------------------------
# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.values)  # Convert to numpy array after scaling

# Add a parameter for the number of features to select after LRP
num_features_after_lrp = 100  # Adjust as needed

# -------------------------------------------------------------
# CROSS-VALIDATION WITH LRP
# -------------------------------------------------------------
for fold in range(num_folds):

    # Reset keras session to reduce model clutter
    tf.keras.backend.clear_session()

    # Define train-test splits
    X_val = X_scaled[chunks[fold]:chunks[fold + 1]]
    y_val = y[chunks[fold]:chunks[fold + 1]][target_column]

    X_train = np.delete(X_scaled, np.arange(chunks[fold], chunks[fold + 1]), axis=0)
    y_train = y.drop(y_val.index)[target_column]

    # Ensure target values are numeric and have the correct shape
    y_train = y_train.astype(float).values
    y_val = y_val.astype(float).values

    # Reshape data for neural network input
    X_train = np.expand_dims(X_train, axis=2)  # Shape: (samples, features, 1)
    X_val = np.expand_dims(X_val, axis=2)      # Shape: (samples, features, 1)

    # Build and train the neural network model
    model = build_cnn_model((X_train.shape[1], 1))  # Input shape: (features, 1)
    model.fit(X_train, y_train, batch_size=32, epochs=150, verbose=0, validation_data=(X_val, y_val))

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)
    relevance_scores = analyzer.analyze(X_train)  # Analyze training data

    # Flatten relevance scores
    relevance_scores_flat = relevance_scores.mean(axis=0).flatten()

    # Store LRP results for original features only
    lrp = pd.DataFrame(relevance_scores_flat, index=X.columns, columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, lrp], axis=1)

    # Predict and store validation results
    predictions = model.predict(X_val).flatten()
    ann_predictions = np.concatenate([ann_predictions, predictions])
    ann_actuals = np.concatenate([ann_actuals, y_val])  # Store actual values for plotting
    history_cache.append(model.history)

# -------------------------------------------------------------
# EVALUATE MODEL PERFORMANCE
# -------------------------------------------------------------
ann_r2 = r2_score(ann_actuals, ann_predictions)  # R² for regression
ann_mse = mean_squared_error(ann_actuals, ann_predictions)  # MSE for regression

print("\nCross Validation Results:\n")
print("Neural Network R2 Score: {:.5f}".format(ann_r2))
print("Mean Squared Error: {:.5f}".format(ann_mse))

# -------------------------------------------------------------
# SELECT TOP FEATURES BASED ON LRP
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

# Select top `num_features_after_lrp` features
selected_features = lrp_cache.head(num_features_after_lrp).index
X_selected = X[selected_features]  # Select only the top features

print(f"\nSelected {num_features_after_lrp} features based on LRP.")

# Save LRP results
lrp_cache.to_csv("lrp_feature_relevance.csv")

# -------------------------------------------------------------
# PLOT PREDICTED VS ACTUAL VALUES
# -------------------------------------------------------------
plt.figure(figsize=(10, 8))
plt.scatter(ann_actuals, ann_predictions, alpha=0.6, edgecolor='k', label="Predictions")
plt.plot([ann_actuals.min(), ann_actuals.max()],
         [ann_actuals.min(), ann_actuals.max()],
         color='red', linestyle='--', label='Ideal Fit')
plt.title("Predicted vs Actual Values (All Folds)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.grid(True)
plt.savefig("predicted_vs_actual_plot.png")
plt.show()
# Out:
# 2024-12-16 17:49:48.350183: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 17:49:48.350202: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 17:49:48.380358: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:48.406004: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense/kernel/v/Assign' id:816 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense/kernel/v, training/Adam/dense/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:48.428957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:48.475064: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:48.506990: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:48.518748: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 17:49:49.786331: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:339 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:49.815646: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/innvestigate/backend/graph.py:467: UserWarning: Ignore dtype <dtype: 'float32'> as bias type.
#   warnings.warn(f"Ignore dtype {dtype} as bias type.")
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/innvestigate/backend/graph.py:480: UserWarning: Ignore dtype <dtype: 'float32'> as bias type.
#   warnings.warn(f"Ignore dtype {dtype} as bias type.")
# 2024-12-16 17:49:55.303021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.312400: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_1/Assign' id:1017 op device:{requested: '', assigned: ''} def:{{{node kernel_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_1, truediv)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.338278: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.408847: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.428482: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:1144 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.453148: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.458354: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:1140 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.484817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.490053: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:1146 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.514497: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.520707: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:960 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.544535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.551286: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:1161 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.576745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.583042: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:1158 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.607167: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.639472: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5' id:1101 op device:{requested: '', assigned: ''} def:{{{node mul_5}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_21, Cast_5)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.665696: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.685871: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.712550: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.719697: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.746394: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.755351: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_8/x' id:1202 op device:{requested: '', assigned: ''} def:{{{node mul_8/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.782359: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.788080: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_3' id:1199 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.814190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.857267: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.863444: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_4' id:1217 op device:{requested: '', assigned: ''} def:{{{node Const_4}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.890726: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.898179: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/range' id:1232 op device:{requested: '', assigned: ''} def:{{{node gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@reversed_kernel_global_average_pooling1d/Mean"], _has_manual_control_dependencies=true](gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/range/start, gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Size, gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.925135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.930854: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/mod' id:1228 op device:{requested: '', assigned: ''} def:{{{node gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@reversed_kernel_global_average_pooling1d/Mean"], _has_manual_control_dependencies=true](gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/add, gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.957157: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.962481: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/ones' id:1234 op device:{requested: '', assigned: ''} def:{{{node gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@reversed_kernel_global_average_pooling1d/Mean"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Shape_1, gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:55.989248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:55.995755: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Const' id:1240 op device:{requested: '', assigned: ''} def:{{{node gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Const}} = Const[_class=["loc:@reversed_kernel_global_average_pooling1d/Mean"], _has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [1] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.024496: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.030519: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Maximum/y' id:1244 op device:{requested: '', assigned: ''} def:{{{node gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Maximum/y}} = Const[_class=["loc:@reversed_kernel_global_average_pooling1d/Mean"], _has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.058764: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.064121: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Const_1' id:1242 op device:{requested: '', assigned: ''} def:{{{node gradients_4/reversed_kernel_global_average_pooling1d/Mean_grad/Const_1}} = Const[_class=["loc:@reversed_kernel_global_average_pooling1d/Mean"], _has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [1] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.090375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.103247: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_4' id:1091 op device:{requested: '', assigned: ''} def:{{{node mul_4}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_19, Cast_4)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.130398: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.150325: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_10/x' id:1262 op device:{requested: '', assigned: ''} def:{{{node mul_10/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.178711: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.185291: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_5' id:1259 op device:{requested: '', assigned: ''} def:{{{node Const_5}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.211769: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.219189: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_5/reversed_kernel_positive_scale_layer_1/mul_grad/Shape_1' id:1268 op device:{requested: '', assigned: ''} def:{{{node gradients_5/reversed_kernel_positive_scale_layer_1/mul_grad/Shape_1}} = Shape[T=DT_FLOAT, _class=["loc:@reversed_kernel_positive_scale_layer_1/mul"], _has_manual_control_dependencies=true, out_type=DT_INT32](mul_4)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.246304: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.286650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.307080: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims_1' id:1284 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_3, reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.334325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.353253: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims/dim' id:1281 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.381072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.387510: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_11/x' id:1290 op device:{requested: '', assigned: ''} def:{{{node mul_11/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.414226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.420540: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_6' id:1287 op device:{requested: '', assigned: ''} def:{{{node Const_6}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.446954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.454081: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims_1' id:1284 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_3, reversed_kernel_positive_conv1d_2/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.481459: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.563614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.583242: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1' id:1328 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_2, reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.613343: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.632569: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims/dim' id:1325 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.662347: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.669005: W tensorflow/c/c_api.cc:304] Operation '{name:'max_pooling1d/ExpandDims/dim' id:117 op device:{requested: '', assigned: ''} def:{{{node max_pooling1d/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: 2>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.699566: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.705770: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.735452: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.742960: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.774554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.784549: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_12/x' id:1334 op device:{requested: '', assigned: ''} def:{{{node mul_12/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.815890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.821832: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_7' id:1331 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.854099: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.862041: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1' id:1328 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_2, reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.891562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.919541: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:1014 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_10, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.949512: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:56.968273: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_13/x' id:1360 op device:{requested: '', assigned: ''} def:{{{node mul_13/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:56.998944: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.005192: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_8' id:1357 op device:{requested: '', assigned: ''} def:{{{node Const_8}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.035692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.043614: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_10/reversed_kernel_positive_scale_layer/mul_grad/Shape_1' id:1366 op device:{requested: '', assigned: ''} def:{{{node gradients_10/reversed_kernel_positive_scale_layer/mul_grad/Shape_1}} = Shape[T=DT_FLOAT, _class=["loc:@reversed_kernel_positive_scale_layer/mul"], _has_manual_control_dependencies=true, out_type=DT_INT32](mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.073650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.120078: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.139214: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1' id:1382 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul, reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.170076: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.190919: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d/Conv1D/ExpandDims/dim' id:1379 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.222781: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.229600: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_14/x' id:1388 op device:{requested: '', assigned: ''} def:{{{node mul_14/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.260545: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.267569: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_9' id:1385 op device:{requested: '', assigned: ''} def:{{{node Const_9}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.298001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:57.305659: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1' id:1382 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul, reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.335661: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 17:49:57.393400: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 17:49:57.929293: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:270 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:57.970171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:58.817054: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-16 17:49:58.817074: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-16 17:49:58.843014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:58.866704: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense/bias/v/Assign' id:821 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense/bias/v, training/Adam/dense/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:58.890216: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:58.938247: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:58.968731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:49:58.980079: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 17:49:59.781990: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:339 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_1_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:49:59.813572: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/innvestigate/backend/graph.py:467: UserWarning: Ignore dtype <dtype: 'float32'> as bias type.
#   warnings.warn(f"Ignore dtype {dtype} as bias type.")
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/innvestigate/backend/graph.py:480: UserWarning: Ignore dtype <dtype: 'float32'> as bias type.
#   warnings.warn(f"Ignore dtype {dtype} as bias type.")
# 2024-12-16 17:50:05.376775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.386368: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_3/Assign' id:1057 op device:{requested: '', assigned: ''} def:{{{node kernel_3/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_3, kernel_3/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.410615: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.488135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.507966: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:1144 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.532227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.537419: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:1140 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.561779: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.567502: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:1146 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.591649: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.598428: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:960 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.622033: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.629538: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_7/x' id:1161 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.653476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.659087: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_2' id:1158 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.684659: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.717410: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_5' id:1101 op device:{requested: '', assigned: ''} def:{{{node mul_5}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_21, Cast_5)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.744945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:05.765803: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:05.792843: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...
# 2024-12-16 17:50:35.885167: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:35.904820: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims/dim' id:1325 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:35.933568: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:35.939727: W tensorflow/c/c_api.cc:304] Operation '{name:'max_pooling1d/ExpandDims/dim' id:117 op device:{requested: '', assigned: ''} def:{{{node max_pooling1d/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: 2>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:35.967272: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:35.972827: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.000590: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.007870: W tensorflow/c/c_api.cc:304] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.035582: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.045385: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_12/x' id:1334 op device:{requested: '', assigned: ''} def:{{{node mul_12/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.073128: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.079241: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_7' id:1331 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.109240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.117023: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1' id:1328 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_2, reversed_kernel_positive_conv1d_1/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.145316: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.173213: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_1' id:1014 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_10, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.201856: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.220339: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_13/x' id:1360 op device:{requested: '', assigned: ''} def:{{{node mul_13/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.249915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.255856: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_8' id:1357 op device:{requested: '', assigned: ''} def:{{{node Const_8}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.284870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.292223: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_10/reversed_kernel_positive_scale_layer/mul_grad/Shape_1' id:1366 op device:{requested: '', assigned: ''} def:{{{node gradients_10/reversed_kernel_positive_scale_layer/mul_grad/Shape_1}} = Shape[T=DT_FLOAT, _class=["loc:@reversed_kernel_positive_scale_layer/mul"], _has_manual_control_dependencies=true, out_type=DT_INT32](mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.322103: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.365621: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.385093: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1' id:1382 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul, reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.413501: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.431775: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d/Conv1D/ExpandDims/dim' id:1379 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.459798: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.465749: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_14/x' id:1388 op device:{requested: '', assigned: ''} def:{{{node mul_14/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.493757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.500127: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_9' id:1385 op device:{requested: '', assigned: ''} def:{{{node Const_9}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.528760: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 17:50:36.536270: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1' id:1382 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul, reversed_kernel_positive_conv1d/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:36.565866: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 17:50:36.625086: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 17:50:37.158206: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/BiasAdd' id:270 op device:{requested: '', assigned: ''} def:{{{node dense_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_1/MatMul, dense_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 17:50:37.187506: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Cross Validation Results:
#
# Neural Network R2 Score: -7.13393
# Mean Squared Error: 839.91551
#
# Top 10 Features by Relevance:
#                                                       Fold_0    Fold_1  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  2.909785  0.272193
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  1.077209  0.783674
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  1.431850  0.643031
# d__Archaea;p__Thermoplasmatota;c__Thermoplasmat...  1.353789  0.443970
# d__Bacteria;p__uncultured;c__uncultured;o__uncu...  1.069619  0.744461
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  1.296473  0.592079
# d__Bacteria;p__Bacteroidota;c__Kapabacteria;o__...  1.323332  0.072641
# d__Bacteria;p__Verrucomicrobiota;c__Omnitrophia...  1.228497 -0.031841
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.545164  0.819883
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  1.162561  0.075771
#
#                                                       Fold_2    Fold_3  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi... -0.487626  0.112293
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__... -0.532600  0.114910
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos... -0.194122  0.069000
# d__Archaea;p__Thermoplasmatota;c__Thermoplasmat... -0.338542  0.053889
# d__Bacteria;p__uncultured;c__uncultured;o__uncu... -0.136010  0.084332
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.032377  0.075379
# d__Bacteria;p__Bacteroidota;c__Kapabacteria;o__... -0.282450  0.051625
# d__Bacteria;p__Verrucomicrobiota;c__Omnitrophia... -0.386704  0.073655
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac... -0.117974  0.068861
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o... -0.165367  0.116026
#
#                                                       Fold_4  \
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...  0.044154
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...  0.042124
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.038370
# d__Archaea;p__Thermoplasmatota;c__Thermoplasmat...  0.030056
# d__Bacteria;p__uncultured;c__uncultured;o__uncu...  0.034544
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...  0.051542
# d__Bacteria;p__Bacteroidota;c__Kapabacteria;o__...  0.024732
# d__Bacteria;p__Verrucomicrobiota;c__Omnitrophia...  0.026583
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...  0.049586
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...  0.042559
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Patescibacteria;c__ABY1;o__Candi...            0.765210
# d__Bacteria;p__Spirochaetota;c__Leptospirae;o__...            0.510103
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...            0.475274
# d__Archaea;p__Thermoplasmatota;c__Thermoplasmat...            0.444049
# d__Bacteria;p__uncultured;c__uncultured;o__uncu...            0.413793
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Chri...            0.409570
# d__Bacteria;p__Bacteroidota;c__Kapabacteria;o__...            0.350956
# d__Bacteria;p__Verrucomicrobiota;c__Omnitrophia...            0.349456
# d__Bacteria;p__Desulfobacterota;c__Syntrophobac...            0.320294
# d__Bacteria;p__Desulfobacterota;c__Syntrophia;o...            0.312457
#
# Selected 100 features based on LRP.

# %% [markdown]
# ## LRP with Leave One Group Out CV

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import LeaveOneGroupOut
import innvestigate

def load_cleaned_data(filepath):
    df = pd.read_csv(filepath)
    print(f"Loaded data from {filepath} with shape {df.shape}")
    # Remove rows with 'x' values
    df = df[~df.isin(['x']).any(axis=1)]
    return df

# Specify your target columns (already defined)
target_columns = [
    "Digester", "Source", "Type", "Waste", "Biomass", 
    "Average-Total-ISD-Cells", "ACE-Xi", "ACE-km",
    "ACE-Ks", "H2-Xi", "H2-km", "H2-Ks"
]

df = load_cleaned_data('Data/df_1.csv')

# Split the DataFrame into features (X) and targets (y)
X = df.drop(columns=target_columns)  # OTU/ASV features
y = df[target_columns]




# -------------------------------------------------------------
# DEFINE CNN MODEL FUNCTION
# -------------------------------------------------------------
def build_cnn_model(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(16, kernel_size=3, activation='relu', input_shape=input_shape),
        tf.keras.layers.Conv1D(32, kernel_size=3, activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])
    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss='mse')
    return model

# -------------------------------------------------------------
# PREPROCESSING
# -------------------------------------------------------------
# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.values)  # Convert to numpy array after scaling

# Define groups (digester groups)
groups = y['Digester']  # Assuming 'Digester' is the column with group info

# Define target column
target_column = 'ACE-km'

# Add a parameter for the number of features to select after LRP
num_features_after_lrp = 100  # Adjust as needed

# -------------------------------------------------------------
# LOGO CV SETUP
# -------------------------------------------------------------
logo = LeaveOneGroupOut()

lrp_cache = pd.DataFrame()
ann_predictions = np.array([])
ann_actuals = np.array([])

for fold, (train_idx, val_idx) in enumerate(logo.split(X_scaled, y[target_column], groups)):
    print(f"Processing Fold {fold + 1}")

    # Split data into training and validation sets
    X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val = y.iloc[train_idx][target_column], y.iloc[val_idx][target_column]

    # Reshape data for neural network input
    X_train = np.expand_dims(X_train, axis=2)  # Shape: (samples, features, 1)
    X_val = np.expand_dims(X_val, axis=2)      # Shape: (samples, features, 1)

    # Build and train the neural network model
    model = build_cnn_model((X_train.shape[1], 1))  # Input shape: (features, 1)
    model.fit(X_train, y_train, batch_size=32, epochs=150, verbose=0, validation_data=(X_val, y_val))

    # Apply LRP
    analyzer = innvestigate.create_analyzer("lrp.z_plus_fast", model)
    relevance_scores = analyzer.analyze(X_train)  # Analyze training data

    # Flatten relevance scores
    relevance_scores_flat = relevance_scores.mean(axis=0).flatten()

    # Store LRP results for original features only
    lrp = pd.DataFrame(relevance_scores_flat, index=X.columns, columns=[f"Fold_{fold}"])
    lrp_cache = pd.concat([lrp_cache, lrp], axis=1)

    # Predict and store validation results
    predictions = model.predict(X_val).flatten()
    ann_predictions = np.concatenate([ann_predictions, predictions])
    ann_actuals = np.concatenate([ann_actuals, y_val])  # Store actual values for plotting

# -------------------------------------------------------------
# EVALUATE MODEL PERFORMANCE
# -------------------------------------------------------------
ann_r2 = r2_score(ann_actuals, ann_predictions)  # R² for regression
ann_mse = mean_squared_error(ann_actuals, ann_predictions)  # MSE for regression

print("\nCross Validation Results:\n")
print("Neural Network R2 Score: {:.5f}".format(ann_r2))
print("Mean Squared Error: {:.5f}".format(ann_mse))

# -------------------------------------------------------------
# SELECT TOP FEATURES BASED ON LRP
# -------------------------------------------------------------
lrp_cache["Mean_Abs_Relevance"] = lrp_cache.abs().mean(axis=1)
lrp_cache = lrp_cache.sort_values("Mean_Abs_Relevance", ascending=False)

print("\nTop 10 Features by Relevance:")
print(lrp_cache.head(10))

# Select top `num_features_after_lrp` features
selected_features = lrp_cache.head(num_features_after_lrp).index
X_selected = X[selected_features]  # Select only the top features

print(f"\nSelected {num_features_after_lrp} features based on LRP.")

# Save LRP results
lrp_cache.to_csv("lrp_feature_relevance.csv")

# -------------------------------------------------------------
# PLOT PREDICTED VS ACTUAL VALUES
# -------------------------------------------------------------
plt.figure(figsize=(10, 8))
plt.scatter(ann_actuals, ann_predictions, alpha=0.6, edgecolor='k', label="Predictions")
plt.plot([ann_actuals.min(), ann_actuals.max()],
         [ann_actuals.min(), ann_actuals.max()],
         color='red', linestyle='--', label='Ideal Fit')
plt.title("Predicted vs Actual Values (LOGO CV)")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.grid(True)
plt.savefig("predicted_vs_actual_plot_logo.png")
plt.show()
# Out:
# Loaded data from Data/df_1.csv with shape (60, 1099)
# Processing Fold 1
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:480: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:481: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# 2024-12-16 18:11:15.825353: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:15.909600: W tensorflow/c/c_api.cc:304] Operation '{name:'training_38/Adam/conv1d_58/bias/m/Assign' id:26862 op device:{requested: '', assigned: ''} def:{{{node training_38/Adam/conv1d_58/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_38/Adam/conv1d_58/bias/m, training_38/Adam/conv1d_58/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:16.597284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:16.814547: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 18:11:17.560832: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_19/mul' id:26716 op device:{requested: '', assigned: ''} def:{{{node loss_19/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_19/mul/x, loss_19/dense_39_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:18.191229: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:22.662364: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:22.736004: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_133/Assign' id:27027 op device:{requested: '', assigned: ''} def:{{{node kernel_133/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_133, kernel_133/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:23.355763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:23.541101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:23.636348: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_228/MaxNeuronSelection_19/Max_grad/range' id:27097 op device:{requested: '', assigned: ''} def:{{{node gradients_228/MaxNeuronSelection_19/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_19/Max"], _has_manual_control_dependencies=true](gradients_228/MaxNeuronSelection_19/Max_grad/range/start, gradients_228/MaxNeuronSelection_19/Max_grad/Size, gradients_228/MaxNeuronSelection_19/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:24.264173: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:24.337700: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_228/MaxNeuronSelection_19/Max_grad/mod' id:27093 op device:{requested: '', assigned: ''} def:{{{node gradients_228/MaxNeuronSelection_19/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_19/Max"], _has_manual_control_dependencies=true](gradients_228/MaxNeuronSelection_19/Max_grad/add, gradients_228/MaxNeuronSelection_19/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:24.967463: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:25.041755: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_228/MaxNeuronSelection_19/Max_grad/ones' id:27099 op device:{requested: '', assigned: ''} def:{{{node gradients_228/MaxNeuronSelection_19/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_19/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_228/MaxNeuronSelection_19/Max_grad/Shape_1, gradients_228/MaxNeuronSelection_19/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:25.672021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:25.746254: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_19/Max/reduction_indices' id:27007 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_19/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:26.377754: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:26.452720: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_289/x' id:27114 op device:{requested: '', assigned: ''} def:{{{node mul_289/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:27.085631: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:27.159382: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_190' id:27111 op device:{requested: '', assigned: ''} def:{{{node Const_190}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:27.800608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:27.881356: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_287' id:27054 op device:{requested: '', assigned: ''} def:{{{node mul_287}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_461, Cast_287)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:28.528345: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:28.632870: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_290/x' id:27138 op device:{requested: '', assigned: ''} def:{{{node mul_290/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:29.336690: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:29.414311: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_191' id:27135 op device:{requested: '', assigned: ''} def:{{{node Const_191}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:30.075271: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:30.782138: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:30.880811: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims_1' id:27155 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_286, reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:31.489721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:31.578931: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims/dim' id:27152 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:32.199825: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:32.276901: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_291/x' id:27161 op device:{requested: '', assigned: ''} def:{{{node mul_291/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:32.895489: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:32.966877: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_192' id:27158 op device:{requested: '', assigned: ''} def:{{{node Const_192}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:33.582055: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:33.657628: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims_1' id:27155 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_286, reversed_kernel_positive_conv1d_58/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:34.263603: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:34.974690: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:35.064958: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims_1' id:27183 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_285, reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:35.679243: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:35.766994: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims/dim' id:27180 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:36.392826: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:36.470859: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_292/x' id:27189 op device:{requested: '', assigned: ''} def:{{{node mul_292/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:37.104450: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:37.179175: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_193' id:27186 op device:{requested: '', assigned: ''} def:{{{node Const_193}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:37.887611: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:37.963210: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims_1' id:27183 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_285, reversed_kernel_positive_conv1d_57/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:38.603417: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 18:11:39.475051: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 18:11:39.925616: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_39/BiasAdd' id:26698 op device:{requested: '', assigned: ''} def:{{{node dense_39/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_39/MatMul, dense_39/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:40.557908: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Processing Fold 2
# 2024-12-16 18:11:41.457234: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:41.541201: W tensorflow/c/c_api.cc:304] Operation '{name:'training_40/Adam/iter/Assign' id:27439 op device:{requested: '', assigned: ''} def:{{{node training_40/Adam/iter/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_INT64, validate_shape=false](training_40/Adam/iter, training_40/Adam/iter/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:42.180721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:42.400440: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 18:11:42.761422: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_20/mul' id:27335 op device:{requested: '', assigned: ''} def:{{{node loss_20/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_20/mul/x, loss_20/dense_41_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:43.400404: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:47.981977: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:48.059123: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_137/Assign' id:27646 op device:{requested: '', assigned: ''} def:{{{node kernel_137/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_137, kernel_137/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:48.699039: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:48.890326: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:48.994177: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_234/MaxNeuronSelection_20/Max_grad/range' id:27716 op device:{requested: '', assigned: ''} def:{{{node gradients_234/MaxNeuronSelection_20/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_20/Max"], _has_manual_control_dependencies=true](gradients_234/MaxNeuronSelection_20/Max_grad/range/start, gradients_234/MaxNeuronSelection_20/Max_grad/Size, gradients_234/MaxNeuronSelection_20/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:49.638828: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:49.715060: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_234/MaxNeuronSelection_20/Max_grad/mod' id:27712 op device:{requested: '', assigned: ''} def:{{{node gradients_234/MaxNeuronSelection_20/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_20/Max"], _has_manual_control_dependencies=true](gradients_234/MaxNeuronSelection_20/Max_grad/add, gradients_234/MaxNeuronSelection_20/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:50.364424: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:50.441638: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_234/MaxNeuronSelection_20/Max_grad/ones' id:27718 op device:{requested: '', assigned: ''} def:{{{node gradients_234/MaxNeuronSelection_20/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_20/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_234/MaxNeuronSelection_20/Max_grad/Shape_1, gradients_234/MaxNeuronSelection_20/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:51.082131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:51.158702: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_20/Max/reduction_indices' id:27626 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_20/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:51.872434: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:51.949570: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_297/x' id:27733 op device:{requested: '', assigned: ''} def:{{{node mul_297/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:52.587669: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:52.664581: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_194' id:27730 op device:{requested: '', assigned: ''} def:{{{node Const_194}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:53.311714: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:53.397508: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_295' id:27673 op device:{requested: '', assigned: ''} def:{{{node mul_295}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_469, Cast_295)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:54.045284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:54.151821: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_298/x' id:27757 op device:{requested: '', assigned: ''} def:{{{node mul_298/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:54.781819: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:54.855029: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_195' id:27754 op device:{requested: '', assigned: ''} def:{{{node Const_195}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:55.593651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:56.408340: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:56.569429: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims_1' id:27774 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_294, reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:57.220178: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:57.314093: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims/dim' id:27771 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:57.952487: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:58.024734: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_299/x' id:27780 op device:{requested: '', assigned: ''} def:{{{node mul_299/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:58.643121: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:58.716735: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_196' id:27777 op device:{requested: '', assigned: ''} def:{{{node Const_196}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:11:59.333451: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:11:59.410173: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims_1' id:27774 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_294, reversed_kernel_positive_conv1d_60/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:00.066756: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:00.851223: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:00.952105: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims_1' id:27802 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_293, reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:01.594116: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:01.695704: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims/dim' id:27799 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:02.314624: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:02.390576: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_300/x' id:27808 op device:{requested: '', assigned: ''} def:{{{node mul_300/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:03.005605: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:03.078783: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_197' id:27805 op device:{requested: '', assigned: ''} def:{{{node Const_197}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:03.685178: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:03.763167: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims_1' id:27802 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_293, reversed_kernel_positive_conv1d_59/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:04.362840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:05.139980: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 18:12:05.436334: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_41/BiasAdd' id:27317 op device:{requested: '', assigned: ''} def:{{{node dense_41/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_41/MatMul, dense_41/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:06.051027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Processing Fold 3
# 2024-12-16 18:12:06.901730: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:06.986092: W tensorflow/c/c_api.cc:304] Operation '{name:'training_42/Adam/decay/Assign' id:28073 op device:{requested: '', assigned: ''} def:{{{node training_42/Adam/decay/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_42/Adam/decay, training_42/Adam/decay/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:07.621951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:07.830217: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-12-16 18:12:08.233986: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_21/mul' id:27954 op device:{requested: '', assigned: ''} def:{{{node loss_21/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_21/mul/x, loss_21/dense_43_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:08.855601: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:13.328656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:13.400292: W tensorflow/c/c_api.cc:304] Operation '{name:'kernel_143/Assign' id:28305 op device:{requested: '', assigned: ''} def:{{{node kernel_143/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_143, kernel_143/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:14.012770: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:14.199873: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:14.301524: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_240/MaxNeuronSelection_21/Max_grad/range' id:28335 op device:{requested: '', assigned: ''} def:{{{node gradients_240/MaxNeuronSelection_21/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_21/Max"], _has_manual_control_dependencies=true](gradients_240/MaxNeuronSelection_21/Max_grad/range/start, gradients_240/MaxNeuronSelection_21/Max_grad/Size, gradients_240/MaxNeuronSelection_21/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:14.926507: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:14.999703: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_240/MaxNeuronSelection_21/Max_grad/mod' id:28331 op device:{requested: '', assigned: ''} def:{{{node gradients_240/MaxNeuronSelection_21/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_21/Max"], _has_manual_control_dependencies=true](gradients_240/MaxNeuronSelection_21/Max_grad/add, gradients_240/MaxNeuronSelection_21/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:15.616663: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:15.690644: W tensorflow/c/c_api.cc:304] Operation '{name:'gradients_240/MaxNeuronSelection_21/Max_grad/ones' id:28337 op device:{requested: '', assigned: ''} def:{{{node gradients_240/MaxNeuronSelection_21/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_21/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_240/MaxNeuronSelection_21/Max_grad/Shape_1, gradients_240/MaxNeuronSelection_21/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:16.321275: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:16.396442: W tensorflow/c/c_api.cc:304] Operation '{name:'MaxNeuronSelection_21/Max/reduction_indices' id:28245 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_21/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:17.025383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:17.103028: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_305/x' id:28352 op device:{requested: '', assigned: ''} def:{{{node mul_305/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:17.728505: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:17.802532: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_198' id:28349 op device:{requested: '', assigned: ''} def:{{{node Const_198}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:18.428840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:18.510566: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_303' id:28292 op device:{requested: '', assigned: ''} def:{{{node mul_303}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_477, Cast_303)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:19.122623: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:19.234016: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_306/x' id:28376 op device:{requested: '', assigned: ''} def:{{{node mul_306/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:19.855062: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:19.931732: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_199' id:28373 op device:{requested: '', assigned: ''} def:{{{node Const_199}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:20.543046: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:21.258149: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:21.354719: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_62/Conv1D/ExpandDims_1' id:28393 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_62/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_302, reversed_kernel_positive_conv1d_62/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:21.985221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:12:22.079556: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_62/Conv1D/ExpandDims/dim' id:28390 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_62/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:12:22.703577: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...
# 2024-12-16 18:19:16.267227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:16.365280: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_259' id:37658 op device:{requested: '', assigned: ''} def:{{{node Const_259}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:17.163809: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:18.027398: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:18.149533: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims_1' id:37678 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_422, reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:18.910720: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:19.028508: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims/dim' id:37675 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:19.791746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:19.885137: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_427/x' id:37684 op device:{requested: '', assigned: ''} def:{{{node mul_427/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:20.639707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:20.739313: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_260' id:37681 op device:{requested: '', assigned: ''} def:{{{node Const_260}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:21.496235: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:21.591478: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims_1' id:37678 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_422, reversed_kernel_positive_conv1d_92/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:22.359633: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:23.264758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:23.384923: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims_1' id:37706 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_421, reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:24.150775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:24.272496: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims/dim' id:37703 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims/dim}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -3>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:25.043162: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:25.140569: W tensorflow/c/c_api.cc:304] Operation '{name:'mul_428/x' id:37712 op device:{requested: '', assigned: ''} def:{{{node mul_428/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:25.908906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:26.006068: W tensorflow/c/c_api.cc:304] Operation '{name:'Const_261' id:37709 op device:{requested: '', assigned: ''} def:{{{node Const_261}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:26.808605: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:26.902745: W tensorflow/c/c_api.cc:304] Operation '{name:'reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims_1' id:37706 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims_1}} = ExpandDims[T=DT_FLOAT, Tdim=DT_INT32, _has_manual_control_dependencies=true](mul_421, reversed_kernel_positive_conv1d_91/Conv1D/ExpandDims_1/dim)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:27.675796: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-16 18:19:28.594841: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/sb/miniforge3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-16 18:19:28.895079: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_73/BiasAdd' id:37221 op device:{requested: '', assigned: ''} def:{{{node dense_73/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_73/MatMul, dense_73/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-16 18:19:29.682431: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Cross Validation Results:
#
# Neural Network R2 Score: -0.15669
# Mean Squared Error: 119.44074
#
# Top 10 Features by Relevance:
#                                                     Fold_0  Fold_1  Fold_2  \
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...     NaN     NaN     NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...     NaN     NaN     NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...     NaN     NaN     NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     NaN     NaN     NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...     NaN     NaN     NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...     NaN     NaN     NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...     NaN     NaN     NaN
#
#                                                     Fold_3  Fold_4  Fold_5  \
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...     NaN     NaN     NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...     NaN     NaN     NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...     NaN     NaN     NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     NaN     NaN     NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...     NaN     NaN     NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...     NaN     NaN     NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...     NaN     NaN     NaN
#
#                                                     Fold_6  Fold_7  Fold_8  \
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...     NaN     NaN     NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...     NaN     NaN     NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...     NaN     NaN     NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     NaN     NaN     NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN     NaN     NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...     NaN     NaN     NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...     NaN     NaN     NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...     NaN     NaN     NaN
#
#                                                     Fold_9  Fold_10  Fold_11  \
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...     NaN      NaN      NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...     NaN      NaN      NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...     NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...     NaN      NaN      NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     NaN      NaN      NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...     NaN      NaN      NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...     NaN      NaN      NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...     NaN      NaN      NaN
#
#                                                     Fold_12  Fold_13  Fold_14  \
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...      NaN      NaN      NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...      NaN      NaN      NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...      NaN      NaN      NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      NaN      NaN      NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      NaN      NaN      NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...      NaN      NaN      NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...      NaN      NaN      NaN
#
#                                                     Fold_15  Fold_16  Fold_17  \
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...      NaN      NaN      NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...      NaN      NaN      NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...      NaN      NaN      NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      NaN      NaN      NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      NaN      NaN      NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      NaN      NaN      NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...      NaN      NaN      NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...      NaN      NaN      NaN
#
#                                                     Mean_Abs_Relevance
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...                 NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...                 NaN
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                 NaN
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 NaN
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                 NaN
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 NaN
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...                 NaN
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...                 NaN
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...                 NaN
# d__Archaea;p__Euryarchaeota;c__Methanobacteria;...                 NaN
#
# Selected 100 features based on LRP.
